# %% [markdown]
# read data

# %%
import pandas as pd
import numpy as np

# %%
trn = open("trn.pos.txt").read().strip().split("\n")

# %%
df_token = []
df_tag = []
tag_list1=[]
tag_list2=[]
for row in trn:
    row_split = row.split()
    tag_list1.append("START")
    for word in row_split:
        token,tag=word.split("/")
        df_token.append(token.lower())
        df_tag.append(tag)
        tag_list1.append(tag)
        tag_list2.append(tag)
    tag_list2.append("END")

# %%
tag_list = list(zip(tag_list1,tag_list2))

# %%
df=pd.DataFrame(df_token)

# %%
df.columns= ["word"]

# %%
count = df.groupby('word')

# %%
df_t=pd.DataFrame(count.size())
df_t.columns= ["frequency"]

# %%
df_unk=[]
df_final=[]
for index, row in df_t.iterrows():
    #print(index,row)
    if row['frequency']<6:
        df_unk.append(index)
    else:
        df_final.append(index)

# %%
df_unk1=pd.DataFrame(df_unk)
df_final1=pd.DataFrame(df_final)

# %%
df_final1.columns= ["word"]
df_unk1.columns= ["UNK"]

# %%
index1=['A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W']
df_final.append('UNK')

# %%
df_emission=pd.DataFrame(index=index1, columns=df_final)
df_emission_s=pd.DataFrame(index=index1, columns=df_final)

# %%
df_num=pd.DataFrame(index=index1, columns=df_final)
df_denom=pd.DataFrame(index=index1, columns=df_final)

# %%
df_num=df_num.fillna(0)
#df_denom=df_denom.fillna(0)

# %%
index=['START','A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W']
column=['A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W','END']

# %%
df_trans=pd.DataFrame(index=index, columns=column)
df_trans_s=pd.DataFrame(index=index, columns=column)

# %%
beta=1
N=12
for index, row in df_trans.iterrows():
    for tag in column:
        count_i=0
        count_t=0
        for i in range(len(tag_list)):
            if tag_list[i][0]==index:
                count_i=count_i+1
                if tag_list[i][1]==tag:
                    count_t=count_t+1
        p=count_t/count_i
        p1=(count_t + beta)/(count_t + (N * beta))
        df_trans.loc[index,tag]=p
        df_trans_s.loc[index,tag]=p1

# %%
j=0
for col in list(df_emission.columns):
    j+=1
    for i,k in enumerate(df_token):
        if col==df_token[i]:
            df_num.loc[df_tag[i],df_token[i]] += 1 
    if j%1000==0:
        print(j)
        print(col)
# Out:
# 1000
# apartments
# 2000
# charlotte
# 3000
# developed
# 4000
# flight
# 5000
# intended
# 6000
# minus
# 7000
# pose
# 8000
# rushed
# 9000
# sweet
# 10000
# winners

# %%
j=0
for unk in list(df_unk):
    j+=1
    for i,k in enumerate(df_token):
        if unk==df_token[i]:
            df_num.loc[df_tag[i],'UNK'] += 1
    if j%1000==0:
        print(j)
        print(unk)
# Out:
# 1000
# 15.375
# 2000
# 24.50
# 3000
# 4.48
# 4000
# 65,200
# 5000
# abb
# 6000
# approving
# 7000
# berol
# 8000
# buzzword
# 9000
# clones
# 10000
# crap
# 11000
# dilute
# 12000
# embarked
# 13000
# fienberg
# 14000
# genova
# 15000
# health-conscious
# 16000
# incriminating
# 17000
# kellwood
# 18000
# lok
# 19000
# merging
# 20000
# nervously
# 21000
# over-40
# 22000
# plurality
# 23000
# rachmaninoff
# 24000
# rice-processing
# 25000
# semi-liquefied
# 26000
# sourcing
# 27000
# surest
# 28000
# tracer
# 29000
# vadas
# 30000
# wrecked

# %%
import numpy as np
tag_corpus_list = np.array(df_tag)
index1=['A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W']
for tags in index1:
    tag_count = len(list(np.where(tag_corpus_list == tags)[0]))
    
    print(tag_count)
    for column in list(df_emission.columns):
        df_denom.loc[tags,column] = tag_count
# Out:
# 71005
# 131480
# 87844
# 10462
# 307388
# 164755
# 36488
# 60879
# 133602
# 9520

# %%
for tags in index1:
    #tag_count = len(list(np.where(tag_corpus_list == tags)[0]))
    
    #print(tag_count)
    for column in list(df_emission.columns):
        df_emission.loc[tags,column] = df_num.loc[tags,column]/df_denom.loc[tags,column]

# %%
for tags in index1:
    #tag_count = len(list(np.where(tag_corpus_list == tags)[0]))
    
    #print(tag_count)
    #for column in list(df_emission.columns):
    df_emission.loc[tags,'UNK'] = df_num.loc[tags,'UNK']/df_denom.loc[tags,'UNK']

# %%
alpha=1
V=len(df_final)
for tags in index1:
    #tag_count = len(list(np.where(tag_corpus_list == tags)[0]))
    
    #print(tag_count)
    for column in list(df_emission.columns):
        df_emission_s.loc[tags,column] = (df_num.loc[tags,column]+ alpha)/(df_denom.loc[tags,column]+ (V * alpha))

# %%
for tags in index1:
    #tag_count = len(list(np.where(tag_corpus_list == tags)[0]))
    
    #print(tag_count)
    #for column in list(df_emission.columns):
    df_emission_s.loc[tags,'UNK'] = (df_num.loc[tags,'UNK']+ alpha)/(df_denom.loc[tags,'UNK']+ (V * alpha))

# %%
#[computingID]-tprob.txt
df_trans.to_csv('og7ut-tprob.csv')
df_emission.to_csv('og7ut-eprob.csv')
df_trans_s.to_csv('og7ut-tprob-smoothed.csv')
df_emission_s.to_csv('og7ut-eprob-smoothed.csv')

# %%
rows=['START','A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W']
columns=['A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W','END']
txt_file = "og7ut-tprob.txt"
with open(txt_file,"w") as output_file:
    for row in rows:
        for column in columns:
            parts = [row,column,str(df_trans.loc[row,column])]
            output_file.write(",".join(parts)+'\n')

# %%
rows=['START','A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W']
columns=['A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W','END']
txt_file = "og7ut-tprob-smoothed.txt"
with open(txt_file,"w") as output_file:
    for row in rows:
        for column in columns:
            parts = [row,column,str(df_trans_s.loc[row,column])]
            output_file.write(",".join(parts)+'\n')

# %%
rows=['A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W']
columns=df_final
txt_file = "og7ut-eprob.txt"
with open(txt_file,"w") as output_file:
    for row in rows:
        for column in columns:
            parts = [row,column,str(df_emission.loc[row,column])]
            output_file.write(",".join(parts)+'\n')

# %%
rows=['A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W']
columns=df_final
txt_file = "og7ut-eprob-smoothed.txt"
with open(txt_file,"w") as output_file:
    for row in rows:
        for column in columns:
            parts = [row,column,str(df_emission_s.loc[row,column])]
            output_file.write(",".join(parts)+'\n')

# %%
df_emission_s

# %%
dev = open("dev.pos.txt").read().strip().split("\n")

# %%
def Viterbi(sentence,df_trans,df_emission,df_final):
    col_len=len(sentence)
    f=0
    tags=['A','C', 'D', 'M', 'N', 'O', 'P', 'R', 'V', 'W']
    numberofwords= list(range(1,col_len))
    sentencewithindex = []
    for i in range(len(sentence)):
        sentencewithindex.append(str(i)+sentence[i])
    df_v=pd.DataFrame(index=tags, columns=sentencewithindex)
    df_b=pd.DataFrame(index=tags, columns=numberofwords)
    #print(df_b)
    prev_word=[]
    y_list=[]
    for i,word in enumerate(sentence):
        if f==0:
            for k in index1:
                #if word in df_final :
                df_v.loc[k,sentencewithindex[i]]=df_trans.loc['START',k]+df_emission.loc[k,word]
            prev_word= sentencewithindex[i]
            f=1
        else:
            for k in index1:
                v=[]
               # print(len(v))
                for tag in tags:
                    #if word in df_final :
                    
                    t1 = df_v.loc[tag,prev_word]+df_trans.loc[tag,k]+df_emission.loc[k,word]
                    #print(df_v.loc[tag,prev_word])
                    #print(df_trans.loc[tag,k])
                    #print(df_emission.loc[k,word])
                    #print("done")
                    v.append(t1)
                    
                df_v.loc[k,sentencewithindex[i]]=np.amax(v)
                #print (t1)
                #print (np.argmax(v))
                df_b.loc[k,i]=tags[np.argmax(v)]
                v=[]
            prev_word= sentencewithindex[i]
        v=[]
    
    for tag in tags:
        t1=df_v.loc[tag,prev_word]+df_trans.loc[tag,'END']
        v.append(t1)
    v_end=np.amax(v)
    b_end=tags[np.argmax(v)]
    y_list.append(b_end)
    for i in range(col_len-1,1,-1):
        t=df_b.loc[b_end,i]
        b_end=t
        y_list.append(t)
    y_list=y_list[::-1]
    return y_list

# %%
df_tag_dev = []
df_tag_pred=[]
i=0
for row in dev:
    i+=1
    if i%1000==0:
        print(i)
    #Viterbi(row,df_trans_s.apply(np.log),df_emission_s.apply(np.log))
    df_token_dev = []
    df_tag_d = []
    row_split = row.split()
    for word in row_split:
        token,tag=word.split("/")
       # print (token)
        if token in df_final:
            df_token_dev.append(token.lower())
        else:
            df_token_dev.append('UNK')
        df_tag_d.append(tag)
    #print(df_token_dev)
    value = Viterbi(df_token_dev,df_trans_s.applymap(np.log),df_emission_s.applymap(np.log),df_final)
    df_tag_pred.append(value)
    df_tag_dev.append(df_tag_d)
    #break
# Out:
# 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-fa77326383b4> in <module>()
#      19         df_tag_d.append(tag)
#      20     #print(df_token_dev)
# ---> 21     value = Viterbi(df_token_dev,df_trans_s.applymap(np.log),df_emission_s.applymap(np.log),df_final)
#      22     df_tag_pred.append(value)
#      23     df_tag_dev.append(df_tag_d)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in applymap(self, func)
#    6060             return lib.map_infer(x.astype(object).values, func)
#    6061
# -> 6062         return self.apply(infer)
#    6063
#    6064     # ----------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     274         else:
#     275             try:
# --> 276                 for i, v in enumerate(series_gen):
#     277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in <genexpr>(.0)
#     324     def series_generator(self):
#     325         return (self.obj._ixs(i, axis=1)
# --> 326                 for i in range(len(self.columns)))
#     327
#     328     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _ixs(self, i, axis)
#    2652                 if index_len and not len(values):
#    2653                     values = np.array([np.nan] * index_len, dtype=object)
# -> 2654                 result = self._box_col_values(values, label)
#    2655
#    2656                 # this is a cached value, mark it so
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _box_col_values(self, values, items)
#    3098         """ provide boxed values for a column """
#    3099         klass = _get_sliced_frame_result_type(values, self)
# -> 3100         return klass(values, index=self.index, name=items, fastpath=True)
#    3101
#    3102     def __setitem__(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     278         generic.NDFrame.__init__(self, data, fastpath=True)
#     279
# --> 280         self.name = name
#     281         self._set_axis(0, index, fastpath=True)
#     282
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4392             object.__setattr__(self, name, value)
#    4393         elif name in self._metadata:
# -> 4394             object.__setattr__(self, name, value)
#    4395         else:
#    4396             try:
#
# KeyboardInterrupt:

# %%
df_actual_tags = []
df_pred_tags = []
for lis in df_tag_pred:
    for val in lis:
        df_pred_tags.append(val)
        
        
for lis in df_tag_dev:
    for val in lis:
        df_actual_tags.append(val)
        
from sklearn.metrics import accuracy_score

print(accuracy_score(df_actual_tags, df_pred_tags)*100)

# %%
tst = open("tst.word.txt").read().strip().split("\n")

# %%
df_tag_dev = []
df_tag_pred=[]
i=0
for row in tst:
    i+=1
    if i%1000==0:
        print(i)
    #Viterbi(row,df_trans_s.apply(np.log),df_emission_s.apply(np.log))
    df_token_dev = []
    #df_tag_d = []
    row_split = row.split()
    for word in row_split:
        token =word
       # print (token)
        if token in df_final:
            df_token_dev.append(token.lower())
        else:
            df_token_dev.append('UNK')
        #df_tag_d.append(tag)
    #print(df_token_dev)
    value = Viterbi(df_token_dev,df_trans_s.applymap(np.log),df_emission_s.applymap(np.log),df_final)
    df_tag_pred.append(value)
    #df_tag_dev.append(df_tag_d)
    #break
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000

# %%
df_tag_pred
# Out:
# [['N',
#   'V',
#   'V',
#   'A',
#   'A',
#   'N',
#   'O',
#   'V',
#   'C',
#   'A',
#   'N',
#   'N',
#   'C',
#   'V',
#   'C',
#   'A',
#   'C',
#   'V',
#   'N',
#   'A',
#   'O',
#   'R',
#   'C',
#   'D',
#   'A',
#   'O'],
#  ['R',
#   'A',
#   'C',
#   'D',
#   'N',
#   'O',
#   'A',
#   'A',
#   'N',
#   'N',
#   'W',
#   'C',
#   'N',
#   'V',
#   'V',
#   'A',
#   'C',
#   'W',
#   'C',
#   'N',
#   'C',
#   'A',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'A',
#   'O',
#   'D',
#   'A',
#   'A',
#   'C',
#   'A',
#   'A',
#   'C',
#   'A',
#   'N',
#   'N',
#   'V',
#   'V',
#   'C',
#   'N',
#   'C',
#   'N',
#   'C',
#   'A',
#   'O',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'O',
#   'C',
#   'D',
#   'A',
#   'A',
#   'C',
#   'A',
#   'O',
#   'A',
#   'P',
#   'C',
#   'A',
#   'A',
#   'A',
#   'W',
#   'N',
#   'V',
#   'C',
#   'N',
#   'O'],
#  ['N',
#   'C',
#   'D',
#   'N',
#   'V',
#   'R',
#   'V',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O',
#   'D',
#   'A',
#   'N',
#   'C',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['R',
#   'O',
#   'N',
#   'N',
#   'V',
#   'A',
#   'C',
#   'A',
#   'N',
#   'N',
#   'V',
#   'A',
#   'R',
#   'C',
#   'M',
#   'C',
#   'N',
#   'V',
#   'C',
#   'D',
#   'N',
#   'P',
#   'A',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'R',
#   'O',
#   'N',
#   'V',
#   'O',
#   'C',
#   'C',
#   'D',
#   'V',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'N',
#   'N',
#   'M',
#   'V',
#   'V',
#   'N',
#   'C',
#   'A',
#   'O',
#   'C',
#   'D',
#   'N',
#   'P',
#   'N',
#   'V',
#   'V',
#   'D',
#   'N',
#   'C',
#   'N',
#   'A'],
#  ['R',
#   'V',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'A',
#   'O',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A', 'V', 'R', 'C', 'W', 'O'],
#  ['O'],
#  ['N',
#   'O',
#   'A',
#   'A',
#   'V',
#   'D',
#   'O',
#   'N',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O',
#   'C',
#   'A',
#   'N',
#   'N',
#   'V',
#   'C',
#   'A',
#   'A',
#   'O',
#   'C',
#   'N',
#   'N',
#   'V',
#   'C',
#   'C',
#   'D',
#   'A',
#   'N',
#   'N',
#   'N',
#   'C',
#   'V',
#   'N',
#   'O'],
#  ['P',
#   'O',
#   'A',
#   'C',
#   'O',
#   'A',
#   'N',
#   'V',
#   'D',
#   'O',
#   'N',
#   'V',
#   'C',
#   'N',
#   'C',
#   'N',
#   'N',
#   'O'],
#  ['N',
#   'A',
#   'V',
#   'O',
#   'R',
#   'O',
#   'A',
#   'C',
#   'A',
#   'N',
#   'V',
#   'O',
#   'C',
#   'O',
#   'V',
#   'O',
#   'A',
#   'N',
#   'O',
#   'C',
#   'A',
#   'C',
#   'A',
#   'N',
#   'A',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'A',
#   'P',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'A',
#   'O',
#   'N',
#   'N',
#   'V',
#   'A',
#   'C',
#   'D',
#   'N',
#   'O',
#   'R',
#   'O',
#   'N',
#   'C',
#   'D',
#   'O',
#   'N',
#   'O',
#   'W',
#   'V',
#   'V',
#   'C',
#   'V',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'A',
#   'P',
#   'A',
#   'V',
#   'N',
#   'N',
#   'C',
#   'D',
#   'N',
#   'R',
#   'N',
#   'V',
#   'A',
#   'O',
#   'D',
#   'V',
#   'C',
#   'O',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O',
#   'D',
#   'N',
#   'P',
#   'N',
#   'N',
#   'V',
#   'O',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'O',
#   'N',
#   'C',
#   'D',
#   'O',
#   'N',
#   'O'],
#  ['D',
#   'O',
#   'N',
#   'O',
#   'A',
#   'P',
#   'A',
#   'V',
#   'O',
#   'N',
#   'R',
#   'O',
#   'O',
#   'O',
#   'O',
#   'C',
#   'O',
#   'A'],
#  ['N', 'O', 'C', 'O', 'A', 'O', 'O', 'C', 'O', 'A'],
#  ['N', 'O'],
#  ['V', 'O', 'N', 'R', 'O', 'A', 'O', 'C', 'O', 'O', 'O', 'O'],
#  ['A',
#   'A',
#   'C',
#   'A',
#   'O',
#   'A',
#   'A',
#   'N',
#   'V',
#   'O',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['V', 'R', 'O', 'A', 'O', 'O', 'C', 'O', 'N'],
#  ['N', 'O', 'C', 'O', 'O', 'O', 'O', 'C', 'O', 'N'],
#  ['N', 'O'],
#  ['A', 'N', 'V', 'D', 'A', 'N', 'C', 'O', 'O', 'O', 'O', 'C', 'O', 'N'],
#  ['N', 'O'],
#  ['V', 'O', 'N', 'R', 'O', 'A', 'O', 'C', 'O', 'A', 'O', 'O'],
#  ['N',
#   'C',
#   'N',
#   'V',
#   'O',
#   'C',
#   'N',
#   'O',
#   'V',
#   'W',
#   'C',
#   'A',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'P',
#   'N',
#   'O'],
#  ['A', 'C', 'D', 'A', 'V', 'O', 'N', 'C', 'D', 'A', 'N', 'O'],
#  ['A', 'A', 'V', 'D', 'A', 'A', 'N', 'A', 'N', 'O'],
#  ['N', 'C', 'D', 'A', 'A', 'V', 'A', 'C', 'O', 'O', 'O', 'O', 'C', 'O', 'N'],
#  ['N', 'O', 'V', 'C', 'D', 'N', 'C', 'O', 'A', 'O', 'O', 'C', 'O', 'N'],
#  ['N', 'O', 'C', 'D', 'A', 'N', 'C', 'O', 'O'],
#  ['A',
#   'A',
#   'O',
#   'D',
#   'N',
#   'P',
#   'N',
#   'C',
#   'A',
#   'A',
#   'N',
#   'O',
#   'V',
#   'N',
#   'V',
#   'R',
#   'V',
#   'V',
#   'C',
#   'W',
#   'C',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['N',
#   'N',
#   'C',
#   'A',
#   'N',
#   'V',
#   'V',
#   'R',
#   'V',
#   'C',
#   'D',
#   'N',
#   'C',
#   'W',
#   'O',
#   'W',
#   'C',
#   'D',
#   'A',
#   'O',
#   'N',
#   'V',
#   'V',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['D', 'N', 'W', 'V', 'N', 'R', 'V', 'O', 'N', 'C', 'O', 'R', 'O', 'O'],
#  ['A',
#   'N',
#   'O',
#   'N',
#   'V',
#   'V',
#   'O',
#   'C',
#   'P',
#   'V',
#   'R',
#   'V',
#   'D',
#   'N',
#   'V',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['C',
#   'A',
#   'N',
#   'C',
#   'D',
#   'N',
#   'M',
#   'V',
#   'D',
#   'A',
#   'N',
#   'N',
#   'R',
#   'V',
#   'N',
#   'C',
#   'A',
#   'N',
#   'A',
#   'O'],
#  ['A',
#   'C',
#   'A',
#   'A',
#   'V',
#   'P',
#   'N',
#   'W',
#   'A',
#   'A',
#   'A',
#   'P',
#   'N',
#   'V',
#   'R',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'C',
#   'C',
#   'A',
#   'N',
#   'N',
#   'C',
#   'P',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['C',
#   'D',
#   'A',
#   'A',
#   'V',
#   'A',
#   'V',
#   'C',
#   'V',
#   'N',
#   'A',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'O',
#   'W'],
#  ['N', 'R', 'V', 'D', 'A', 'O'],
#  ['A',
#   'A',
#   'A',
#   'V',
#   'V',
#   'R',
#   'N',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'C',
#   'V',
#   'A',
#   'N',
#   'N',
#   'C',
#   'P',
#   'A',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'V',
#   'C',
#   'W',
#   'C',
#   'P',
#   'N',
#   'O',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'A',
#   'P',
#   'A',
#   'A',
#   'N',
#   'V',
#   'V',
#   'R',
#   'R',
#   'O',
#   'C',
#   'O',
#   'V',
#   'A',
#   'N',
#   'W',
#   'N',
#   'M',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'A',
#   'V',
#   'V',
#   'R',
#   'N',
#   'V',
#   'N',
#   'O',
#   'R',
#   'C',
#   'C',
#   'V',
#   'N',
#   'N',
#   'C',
#   'N',
#   'N',
#   'V',
#   'C',
#   'D',
#   'V',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['R', 'N', 'O', 'N', 'V', 'R', 'V', 'C', 'A', 'A', 'N', 'C', 'A', 'O'],
#  ['A',
#   'V',
#   'V',
#   'V',
#   'N',
#   'C',
#   'A',
#   'A',
#   'N',
#   'C',
#   'D',
#   'R',
#   'A',
#   'N',
#   'N',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'V',
#   'C',
#   'V',
#   'N',
#   'C',
#   'D',
#   'V',
#   'A',
#   'V',
#   'N',
#   'C',
#   'P',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'P',
#   'A',
#   'A',
#   'O',
#   'C',
#   'V',
#   'V',
#   'N',
#   'W',
#   'N',
#   'V',
#   'R',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['O',
#   'N',
#   'N',
#   'R',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'C',
#   'P',
#   'A',
#   'A',
#   'N',
#   'O',
#   'A',
#   'C',
#   'D',
#   'A',
#   'A',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'A',
#   'N',
#   'V',
#   'V',
#   'R',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'N',
#   'O',
#   'W',
#   'A',
#   'O',
#   'V',
#   'V',
#   'R',
#   'D',
#   'A',
#   'N',
#   'C',
#   'N',
#   'V',
#   'V',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'A',
#   'V',
#   'P',
#   'V',
#   'V',
#   'C',
#   'D',
#   'N',
#   'C',
#   'P',
#   'A',
#   'A',
#   'N',
#   'O',
#   'V',
#   'W',
#   'D',
#   'N',
#   'V',
#   'R',
#   'A',
#   'W',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['N',
#   'C',
#   'A',
#   'A',
#   'V',
#   'D',
#   'N',
#   'C',
#   'O',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'V',
#   'A',
#   'C',
#   'D',
#   'N',
#   'P',
#   'C',
#   'O',
#   'O',
#   'O',
#   'N',
#   'N',
#   'C',
#   'A',
#   'C',
#   'D',
#   'N',
#   'N',
#   'V',
#   'C',
#   'D',
#   'A',
#   'N',
#   'R',
#   'A',
#   'A',
#   'C',
#   'V',
#   'N',
#   'R',
#   'V',
#   'W',
#   'O'],
#  ['A',
#   'V',
#   'P',
#   'V',
#   'W',
#   'D',
#   'N',
#   'O',
#   'V',
#   'C',
#   'A',
#   'N',
#   'C',
#   'A',
#   'O',
#   'V',
#   'C',
#   'W',
#   'O'],
#  ['V', 'A', 'A', 'V', 'V', 'C', 'A', 'O', 'A', 'O'],
#  ['N'],
#  ['V', 'D', 'N', 'V', 'A', 'A', 'A', 'C', 'A', 'A', 'A', 'O'],
#  ['A', 'A', 'V', 'P', 'V', 'R', 'N', 'D', 'A', 'N', 'C', 'D', 'A', 'N'],
#  ['V', 'A', 'O', 'C', 'V', 'V', 'A', 'N', 'O'],
#  ['N',
#   'C',
#   'A',
#   'N',
#   'C',
#   'N',
#   'V',
#   'P',
#   'V',
#   'V',
#   'D',
#   'N',
#   'C',
#   'N',
#   'N',
#   'O',
#   'V',
#   'V',
#   'N',
#   'C',
#   'P',
#   'N',
#   'N',
#   'O'],
#  ['V',
#   'R',
#   'N',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'M',
#   'R',
#   'V',
#   'C',
#   'P',
#   'V',
#   'R',
#   'V',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['D',
#   'N',
#   'V',
#   'A',
#   'O',
#   'O',
#   'O',
#   'O',
#   'A',
#   'V',
#   'A',
#   'N',
#   'C',
#   'O',
#   'O',
#   'O',
#   'O',
#   'C',
#   'O',
#   'A'],
#  ['N', 'O'],
#  ['N', 'V', 'R', 'V', 'R', 'P', 'A', 'N', 'O'],
#  ['D', 'A', 'O', 'N', 'A', 'N', 'V', 'O', 'O', 'O', 'O', 'C', 'O', 'A'],
#  ['N', 'O', 'C', 'N', 'C', 'O', 'A', 'O', 'O'],
#  ['O',
#   'D',
#   'N',
#   'V',
#   'P',
#   'M',
#   'V',
#   'D',
#   'V',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'A',
#   'O',
#   'C',
#   'R',
#   'O',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'D',
#   'V',
#   'V',
#   'C',
#   'N',
#   'C',
#   'A',
#   'P',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['D',
#   'N',
#   'V',
#   'C',
#   'A',
#   'N',
#   'C',
#   'A',
#   'R',
#   'V',
#   'A',
#   'N',
#   'R',
#   'D',
#   'A',
#   'N',
#   'N',
#   'O',
#   'A',
#   'V',
#   'P',
#   'M',
#   'V',
#   'D',
#   'O',
#   'O',
#   'N',
#   'N',
#   'R',
#   'V',
#   'W',
#   'R',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'A',
#   'V',
#   'D',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'V',
#   'W',
#   'D',
#   'N',
#   'C',
#   'A',
#   'R',
#   'D',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'V',
#   'C',
#   'A',
#   'A',
#   'V',
#   'O',
#   'C',
#   'W',
#   'O'],
#  ['O'],
#  ['O',
#   'V',
#   'C',
#   'A',
#   'O',
#   'A',
#   'O',
#   'V',
#   'V',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'W',
#   'A',
#   'P',
#   'A',
#   'N',
#   'N',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['N', 'V', 'V', 'R', 'A', 'A', 'O', 'D', 'A', 'A', 'V', 'C', 'N', 'N', 'O'],
#  ['P',
#   'N',
#   'O',
#   'A',
#   'V',
#   'V',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'R',
#   'V',
#   'A',
#   'C',
#   'V',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'N',
#   'V',
#   'D',
#   'N',
#   'V',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'P',
#   'N',
#   'C',
#   'O',
#   'N',
#   'R',
#   'O',
#   'N',
#   'C',
#   'P',
#   'N',
#   'O'],
#  ['D',
#   'N',
#   'V',
#   'A',
#   'O',
#   'O',
#   'O',
#   'O',
#   'A',
#   'V',
#   'O',
#   'O',
#   'O',
#   'O',
#   'C',
#   'O',
#   'N'],
#  ['N', 'O', 'C', 'N', 'C', 'O', 'A', 'O', 'O'],
#  ['V',
#   'D',
#   'N',
#   'P',
#   'N',
#   'V',
#   'V',
#   'C',
#   'N',
#   'C',
#   'D',
#   'O',
#   'A',
#   'N',
#   'O',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'N',
#   'R',
#   'O',
#   'C',
#   'P',
#   'M',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['V',
#   'P',
#   'V',
#   'V',
#   'O',
#   'D',
#   'C',
#   'P',
#   'N',
#   'C',
#   'A',
#   'C',
#   'D',
#   'N',
#   'O',
#   'V',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'A',
#   'N',
#   'V',
#   'W',
#   'P',
#   'V',
#   'R',
#   'O',
#   'A',
#   'P',
#   'A',
#   'W',
#   'O',
#   'C',
#   'A',
#   'P',
#   'N',
#   'O',
#   'V',
#   'D',
#   'V',
#   'W',
#   'P'],
#  ['R', 'A', 'C', 'A', 'P', 'N', 'O'],
#  ['V',
#   'W',
#   'D',
#   'N',
#   'V',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O',
#   'R',
#   'V',
#   'D',
#   'N',
#   'C',
#   'N',
#   'C',
#   'A',
#   'P',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['C',
#   'D',
#   'N',
#   'C',
#   'W',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'V',
#   'N',
#   'N',
#   'A',
#   'C',
#   'A',
#   'A',
#   'A',
#   'V',
#   'P',
#   'M',
#   'V',
#   'P',
#   'A',
#   'N',
#   'R',
#   'C',
#   'A',
#   'C',
#   'C',
#   'N',
#   'C',
#   'V',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['A',
#   'O',
#   'N',
#   'N',
#   'C',
#   'V',
#   'C',
#   'D',
#   'A',
#   'O',
#   'A',
#   'O',
#   'N',
#   'O',
#   'V',
#   'C',
#   'D',
#   'N',
#   'W',
#   'D',
#   'V',
#   'A',
#   'C',
#   'A',
#   'O',
#   'R',
#   'V',
#   'P',
#   'A',
#   'N',
#   'O',
#   'O',
#   'V',
#   'V',
#   'D',
#   'N',
#   'C',
#   'P',
#   'A',
#   'O',
#   'C',
#   'W',
#   'A',
#   'C',
#   'O',
#   'N'],
#  ['V',
#   'A',
#   'R',
#   'V',
#   'R',
#   'C',
#   'A',
#   'C',
#   'A',
#   'N',
#   'M',
#   'R',
#   'V',
#   'V',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'A',
#   'V',
#   'A',
#   'A',
#   'W',
#   'D',
#   'A',
#   'P',
#   'V',
#   'V',
#   'R',
#   'V',
#   'D',
#   'N',
#   'M',
#   'R',
#   'V',
#   'V',
#   'C',
#   'A',
#   'O',
#   'O',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'V',
#   'V',
#   'V',
#   'R',
#   'A',
#   'N',
#   'C',
#   'A',
#   'C',
#   'O',
#   'A',
#   'N',
#   'O',
#   'V',
#   'O',
#   'A',
#   'R',
#   'A',
#   'C',
#   'O',
#   'A',
#   'R',
#   'A',
#   'A',
#   'O'],
#  ['O', 'D', 'N', 'V', 'R', 'V', 'R', 'V', 'C', 'A', 'O'],
#  ['V', 'R', 'V', 'R', 'V', 'R', 'A', 'A'],
#  ['A', 'A', 'N', 'C', 'R', 'C', 'D', 'A', 'C', 'N', 'P', 'N', 'O'],
#  ['O', 'R', 'O', 'V', 'R', 'A', 'R', 'V', 'A', 'O'],
#  ['D',
#   'N',
#   'O',
#   'D',
#   'A',
#   'A',
#   'A',
#   'N',
#   'O',
#   'V',
#   'P',
#   'A',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O',
#   'A',
#   'O',
#   'A',
#   'O',
#   'A',
#   'O',
#   'C',
#   'A',
#   'O',
#   'A',
#   'O',
#   'V',
#   'V',
#   'V',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'W',
#   'O'],
#  ['O',
#   'D',
#   'N',
#   'P',
#   'N',
#   'A',
#   'D',
#   'A',
#   'N',
#   'W',
#   'D',
#   'A',
#   'N',
#   'A',
#   'C',
#   'N',
#   'M',
#   'V',
#   'C',
#   'A',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['R', 'V', 'A', 'R', 'V', 'D', 'N', 'V', 'V', 'N', 'C', 'D', 'N', 'O'],
#  ['A',
#   'R',
#   'V',
#   'R',
#   'V',
#   'W',
#   'D',
#   'N',
#   'M',
#   'R',
#   'V',
#   'C',
#   'M',
#   'V',
#   'D',
#   'A',
#   'A',
#   'O',
#   'O',
#   'A',
#   'A',
#   'O',
#   'N',
#   'C',
#   'A',
#   'P',
#   'A',
#   'A',
#   'O',
#   'V',
#   'C',
#   'D',
#   'N',
#   'N',
#   'O'],
#  ['A', 'V', 'R', 'V', 'P', 'N', 'M', 'C', 'P', 'R', 'A', 'O'],
#  ['O'],
#  ['A',
#   'O',
#   'C',
#   'O',
#   'V',
#   'D',
#   'A',
#   'N',
#   'C',
#   'R',
#   'A',
#   'V',
#   'C',
#   'D',
#   'V',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'A',
#   'C',
#   'P',
#   'N',
#   'M',
#   'V',
#   'O'],
#  ['A',
#   'N',
#   'W',
#   'A',
#   'C',
#   'A',
#   'R',
#   'V',
#   'A',
#   'D',
#   'A',
#   'N',
#   'V',
#   'D',
#   'D',
#   'N',
#   'C',
#   'P',
#   'A',
#   'O',
#   'P',
#   'M',
#   'R',
#   'V',
#   'O',
#   'C',
#   'D',
#   'O',
#   'O',
#   'A',
#   'A',
#   'V',
#   'O'],
#  ['O',
#   'D',
#   'A',
#   'V',
#   'A',
#   'V',
#   'R',
#   'V',
#   'R',
#   'V',
#   'W',
#   'D',
#   'N',
#   'V',
#   'V',
#   'A',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'D',
#   'A',
#   'A',
#   'V',
#   'C',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'V',
#   'R',
#   'V',
#   'D',
#   'N',
#   'C',
#   'N',
#   'O'],
#  ['A', 'P', 'R', 'R', 'R', 'N', 'O', 'A', 'P', 'V', 'P'],
#  ['M', 'R', 'V', 'D', 'N', 'O', 'O', 'V', 'D', 'A', 'N', 'O'],
#  ['N', 'C', 'A', 'A', 'V', 'A', 'V', 'V', 'A', 'A'],
#  ['M', 'V', 'D', 'A', 'C', 'N', 'R', 'D', 'N', 'O'],
#  ['V',
#   'V',
#   'R',
#   'V',
#   'N',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'A',
#   'C',
#   'O',
#   'A',
#   'A',
#   'N',
#   'C',
#   'V',
#   'R',
#   'V',
#   'D',
#   'N',
#   'C',
#   'W',
#   'M',
#   'O'],
#  ['A',
#   'O',
#   'D',
#   'A',
#   'N',
#   'V',
#   'W',
#   'D',
#   'N',
#   'V',
#   'V',
#   'C',
#   'A',
#   'N',
#   'C',
#   'D',
#   'C',
#   'P',
#   'N',
#   'C',
#   'W',
#   'P',
#   'V',
#   'A',
#   'R',
#   'V',
#   'W'],
#  ['W', 'M', 'V', 'V', 'C', 'D', 'N', 'O'],
#  ['O',
#   'W',
#   'C',
#   'A',
#   'N',
#   'V',
#   'V',
#   'V',
#   'R',
#   'V',
#   'D',
#   'O',
#   'N',
#   'O',
#   'R',
#   'W',
#   'C',
#   'A',
#   'A',
#   'W',
#   'C',
#   'D',
#   'N',
#   'P',
#   'A',
#   'O',
#   'A',
#   'O',
#   'N',
#   'O',
#   'W',
#   'V',
#   'D',
#   'C',
#   'V',
#   'C',
#   'D',
#   'A',
#   'O'],
#  ['C',
#   'A',
#   'O',
#   'O',
#   'V',
#   'V',
#   'V',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'D',
#   'A',
#   'O',
#   'V',
#   'V',
#   'R',
#   'V',
#   'A',
#   'R',
#   'C',
#   'D',
#   'N',
#   'R',
#   'A',
#   'A',
#   'O'],
#  ['N', 'V', 'R', 'V', 'V', 'R', 'V', 'R', 'R', 'D', 'N', 'N', 'O'],
#  ['A', 'V', 'R', 'V', 'A', 'P', 'V', 'W'],
#  ['V', 'C', 'P', 'V', 'R', 'O', 'O', 'V', 'A', 'A', 'O', 'D', 'A', 'N'],
#  ['V', 'V', 'C', 'W', 'C', 'D'],
#  ['C', 'D', 'N', 'V', 'O'],
#  ['N', 'N', 'O', 'C', 'O', 'O', 'V', 'V', 'V', 'D', 'A', 'N', 'O'],
#  ['A',
#   'P',
#   'N',
#   'N',
#   'V',
#   'V',
#   'C',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'A',
#   'O',
#   'P',
#   'R',
#   'V',
#   'V',
#   'C',
#   'D',
#   'A',
#   'O',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'N',
#   'V',
#   'V',
#   'O',
#   'N',
#   'O',
#   'W',
#   'D',
#   'N',
#   'N',
#   'M',
#   'V',
#   'V',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'W',
#   'N',
#   'V',
#   'R',
#   'A',
#   'C',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['P',
#   'N',
#   'V',
#   'O',
#   'O',
#   'A',
#   'R',
#   'R',
#   'C',
#   'O',
#   'A',
#   'C',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'A',
#   'V',
#   'P',
#   'V',
#   'D',
#   'A',
#   'D',
#   'N',
#   'M',
#   'V',
#   'V',
#   'M',
#   'V',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'A',
#   'W',
#   'D',
#   'N',
#   'C',
#   'N',
#   'M',
#   'V',
#   'N',
#   'C',
#   'A',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['O', 'P', 'V', 'O', 'P', 'P', 'A', 'W', 'D', 'N', 'M', 'A', 'R', 'R', 'O'],
#  ['N', 'M', 'R', 'V', 'D', 'A', 'N', 'R', 'N', 'O'],
#  ['O'],
#  ['N', 'O', 'A', 'A', 'A', 'A', 'V', 'A', 'N'],
#  ['N',
#   'O',
#   'V',
#   'W',
#   'O',
#   'R',
#   'P',
#   'M',
#   'O',
#   'A',
#   'P',
#   'N',
#   'V',
#   'D',
#   'A',
#   'A',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['O'],
#  ['A',
#   'A',
#   'V',
#   'D',
#   'N',
#   'O',
#   'C',
#   'D',
#   'N',
#   'P',
#   'N',
#   'C',
#   'D',
#   'O',
#   'N',
#   'N',
#   'V',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'C',
#   'N',
#   'O',
#   'O',
#   'R',
#   'A',
#   'O'],
#  ['A',
#   'V',
#   'W',
#   'D',
#   'N',
#   'A',
#   'D',
#   'N',
#   'P',
#   'V',
#   'C',
#   'D',
#   'N',
#   'P',
#   'A',
#   'C',
#   'V',
#   'V',
#   'R',
#   'V',
#   'A',
#   'N',
#   'R',
#   'O'],
#  ['A', 'N', 'O'],
#  ['A',
#   'V',
#   'A',
#   'R',
#   'C',
#   'A',
#   'N',
#   'C',
#   'A',
#   'A',
#   'C',
#   'D',
#   'A',
#   'O',
#   'A',
#   'O',
#   'N',
#   'N',
#   'O'],
#  ['N', 'V', 'V', 'R', 'V', 'C', 'P', 'V', 'N', 'O', 'R', 'O'],
#  ['V',
#   'V',
#   'D',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O',
#   'C',
#   'W',
#   'V',
#   'V',
#   'V',
#   'R',
#   'R',
#   'O'],
#  ['A',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O',
#   'W',
#   'V',
#   'O',
#   'N',
#   'C',
#   'A',
#   'P',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O',
#   'A',
#   'O',
#   'V',
#   'P',
#   'V',
#   'R',
#   'V',
#   'P',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'C',
#   'D',
#   'A',
#   'W',
#   'R',
#   'V',
#   'O',
#   'C',
#   'P',
#   'V',
#   'W',
#   'O'],
#  ['N', 'V', 'N', 'O'],
#  ['A',
#   'A',
#   'C',
#   'A',
#   'V',
#   'P',
#   'V',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'C',
#   'O',
#   'N',
#   'A',
#   'A',
#   'A',
#   'V',
#   'C',
#   'D',
#   'A',
#   'C',
#   'C',
#   'O',
#   'A',
#   'O',
#   'O'],
#  ['N',
#   'O',
#   'A',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'O',
#   'M',
#   'V',
#   'V',
#   'C',
#   'A',
#   'C',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['C', 'A', 'V', 'D', 'N', 'C', 'A', 'A', 'A', 'O'],
#  ['A', 'V', 'V', 'C', 'A', 'O'],
#  ['A',
#   'N',
#   'V',
#   'D',
#   'N',
#   'N',
#   'C',
#   'D',
#   'N',
#   'V',
#   'R',
#   'V',
#   'V',
#   'R',
#   'O',
#   'C',
#   'D',
#   'N',
#   'C',
#   'N',
#   'O',
#   'C',
#   'R',
#   'C',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['O'],
#  ['A', 'V', 'R', 'D', 'N', 'O'],
#  ['N', 'M', 'R', 'V', 'V', 'C', 'A', 'C', 'D', 'A', 'N', 'O'],
#  ['C', 'A', 'A', 'V', 'R', 'V', 'V', 'A', 'N'],
#  ['A', 'A'],
#  ['M', 'V', 'R', 'D', 'A', 'A', 'C', 'A', 'O'],
#  ['V',
#   'V',
#   'C',
#   'A',
#   'V',
#   'C',
#   'A',
#   'W',
#   'A',
#   'N',
#   'V',
#   'V',
#   'A',
#   'N',
#   'C',
#   'V',
#   'A',
#   'O'],
#  ['R',
#   'N',
#   'A',
#   'P',
#   'V',
#   'N',
#   'W',
#   'P',
#   'A',
#   'N',
#   'O',
#   'A',
#   'C',
#   'A',
#   'A',
#   'O',
#   'M',
#   'V',
#   'P',
#   'A',
#   'R',
#   'D',
#   'A',
#   'O'],
#  ['A',
#   'W',
#   'A',
#   'V',
#   'A',
#   'O',
#   'N',
#   'R',
#   'C',
#   'A',
#   'W',
#   'A',
#   'V',
#   'D',
#   'A',
#   'A',
#   'O',
#   'V',
#   'A',
#   'O',
#   'W',
#   'R',
#   'V',
#   'D',
#   'O',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['A', 'V', 'R', 'V', 'R', 'V', 'V', 'R', 'O', 'O', 'V', 'O', 'N', 'A', 'O'],
#  ['C',
#   'A',
#   'O',
#   'A',
#   'O',
#   'V',
#   'A',
#   'P',
#   'A',
#   'A',
#   'A',
#   'O',
#   'R',
#   'V',
#   'V',
#   'A',
#   'C',
#   'A',
#   'A',
#   'O',
#   'M',
#   'V',
#   'C',
#   'W',
#   'C',
#   'W',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O'],
#  ['A', 'N', 'V', 'W', 'N', 'R', 'A', 'V', 'A', 'A', 'N', 'O'],
#  ['V', 'D', 'N', 'M', 'N', 'N', 'C', 'D', 'N', 'C', 'V', 'R', 'N', 'O'],
#  ['V', 'R', 'R', 'A', 'C', 'A', 'O'],
#  ['N', 'V', 'D', 'A', 'A', 'A', 'C', 'A', 'C', 'V', 'D', 'N', 'C', 'A', 'O'],
#  ['A',
#   'V',
#   'D',
#   'M',
#   'C',
#   'O',
#   'O',
#   'A',
#   'P',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'V',
#   'R',
#   'C',
#   'O',
#   'N',
#   'C',
#   'A',
#   'C',
#   'O',
#   'N',
#   'O'],
#  ['D',
#   'V',
#   'C',
#   'A',
#   'A',
#   'O',
#   'A',
#   'P',
#   'N',
#   'V',
#   'R',
#   'V',
#   'R',
#   'V',
#   'O',
#   'N',
#   'O'],
#  ['D',
#   'A',
#   'V',
#   'V',
#   'D',
#   'A',
#   'N',
#   'C',
#   'N',
#   'C',
#   'V',
#   'N',
#   'O',
#   'D',
#   'A',
#   'N',
#   'C',
#   'N',
#   'M',
#   'V',
#   'C',
#   'D',
#   'O',
#   'O',
#   'O',
#   'A',
#   'A',
#   'N',
#   'O',
#   'W',
#   'N',
#   'V',
#   'A',
#   'C',
#   'A',
#   'V',
#   'V',
#   'A',
#   'C',
#   'A',
#   'O'],
#  ['N',
#   'M',
#   'V',
#   'V',
#   'R',
#   'N',
#   'D',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'P',
#   'P',
#   'R',
#   'V',
#   'P',
#   'A',
#   'A',
#   'C',
#   'O',
#   'A',
#   'A',
#   'O',
#   'V',
#   'D',
#   'N',
#   'P',
#   'A',
#   'V',
#   'O',
#   'A',
#   'C',
#   'A',
#   'O'],
#  ['A', 'O', 'R', 'O', 'P', 'V', 'R', 'R', 'A', 'R', 'V', 'N'],
#  ['A',
#   'V',
#   'A',
#   'O',
#   'A',
#   'N',
#   'V',
#   'R',
#   'V',
#   'R',
#   'A',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'A',
#   'W',
#   'P',
#   'V',
#   'D',
#   'N',
#   'C',
#   'A',
#   'R',
#   'R',
#   'A',
#   'D',
#   'A',
#   'O'],
#  ['D',
#   'A',
#   'O',
#   'O',
#   'A',
#   'V',
#   'R',
#   'V',
#   'R',
#   'D',
#   'V',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'N',
#   'W',
#   'P',
#   'N',
#   'C',
#   'A',
#   'O'],
#  ['D',
#   'N',
#   'O',
#   'W',
#   'V',
#   'R',
#   'C',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'O',
#   'A',
#   'C',
#   'D',
#   'N',
#   'N',
#   'C',
#   'A',
#   'C',
#   'V',
#   'V',
#   'O'],
#  ['C',
#   'N',
#   'R',
#   'V',
#   'V',
#   'R',
#   'R',
#   'W',
#   'N',
#   'C',
#   'A',
#   'C',
#   'W',
#   'A',
#   'A',
#   'C',
#   'A',
#   'O',
#   'C',
#   'P',
#   'V',
#   'R',
#   'V',
#   'R',
#   'O',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['A', 'V', 'D', 'A', 'A', 'V', 'D', 'A', 'N'],
#  ['R', 'V', 'D', 'A'],
#  ['V', 'W', 'C', 'A', 'O'],
#  ['N',
#   'V',
#   'V',
#   'R',
#   'A',
#   'D',
#   'N',
#   'O',
#   'C',
#   'N',
#   'C',
#   'P',
#   'M',
#   'V',
#   'R',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['A',
#   'N',
#   'N',
#   'V',
#   'A',
#   'O',
#   'A',
#   'V',
#   'A',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O'],
#  ['C', 'R', 'A', 'N', 'A', 'C', 'N', 'O', 'W', 'P', 'D', 'R', 'D', 'N', 'O'],
#  ['D',
#   'A',
#   'A',
#   'V',
#   'R',
#   'O',
#   'D',
#   'N',
#   'C',
#   'A',
#   'N',
#   'V',
#   'A',
#   'R',
#   'V',
#   'C',
#   'N',
#   'V',
#   'C',
#   'P',
#   'A',
#   'A',
#   'O'],
#  ['N',
#   'O',
#   'M',
#   'R',
#   'V',
#   'D',
#   'O',
#   'A',
#   'O',
#   'N',
#   'R',
#   'R',
#   'O',
#   'O',
#   'P',
#   'V',
#   'O'],
#  ['V',
#   'V',
#   'R',
#   'V',
#   'A',
#   'C',
#   'A',
#   'A',
#   'D',
#   'N',
#   'C',
#   'A',
#   'C',
#   'D',
#   'A',
#   'O'],
#  ['V',
#   'A',
#   'O',
#   'N',
#   'M',
#   'R',
#   'V',
#   'D',
#   'A',
#   'N',
#   'V',
#   'A',
#   'N',
#   'N',
#   'R',
#   'C',
#   'D',
#   'A',
#   'A',
#   'O',
#   'W',
#   'V',
#   'C',
#   'O',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['N',
#   'R',
#   'V',
#   'V',
#   'P',
#   'V',
#   'A',
#   'C',
#   'V',
#   'A',
#   'C',
#   'D',
#   'A',
#   'O',
#   'C',
#   'R',
#   'R',
#   'D',
#   'N',
#   'V',
#   'V',
#   'C',
#   'N',
#   'O',
#   'A',
#   'C',
#   'A',
#   'N',
#   'P',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O',
#   'D',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['R', 'V', 'D', 'A', 'N', 'C', 'A', 'O'],
#  ['V',
#   'A',
#   'P',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'V',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'A',
#   'O'],
#  ['A', 'V', 'N'],
#  ['M', 'V', 'C', 'C', 'C', 'A', 'O', 'O', 'V', 'A', 'A', 'O'],
#  ['A',
#   'V',
#   'W',
#   'P',
#   'V',
#   'N',
#   'C',
#   'P',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'A',
#   'O',
#   'C',
#   'W',
#   'D',
#   'N',
#   'V',
#   'R',
#   'V',
#   'P',
#   'A',
#   'A',
#   'N',
#   'C',
#   'V',
#   'N',
#   'O'],
#  ['A',
#   'N',
#   'C',
#   'N',
#   'N',
#   'O',
#   'V',
#   'C',
#   'N',
#   'N',
#   'O',
#   'V',
#   'P',
#   'V',
#   'D',
#   'A'],
#  ['M',
#   'R',
#   'V',
#   'A',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'P',
#   'A',
#   'N',
#   'O',
#   'C',
#   'A',
#   'N',
#   'C',
#   'N',
#   'O'],
#  ['A',
#   'N',
#   'V',
#   'C',
#   'D',
#   'A',
#   'N',
#   'A',
#   'O',
#   'O',
#   'W',
#   'D',
#   'A',
#   'N',
#   'V',
#   'A',
#   'O'],
#  ['V',
#   'P',
#   'V',
#   'R',
#   'A',
#   'P',
#   'A',
#   'R',
#   'V',
#   'A',
#   'N',
#   'C',
#   'R',
#   'C',
#   'P',
#   'N',
#   'V',
#   'V',
#   'O'],
#  ['A',
#   'O',
#   'O',
#   'N',
#   'A',
#   'O',
#   'V',
#   'V',
#   'N',
#   'C',
#   'D',
#   'M',
#   'C',
#   'W',
#   'N',
#   'O',
#   'V',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O',
#   'O',
#   'O',
#   'W',
#   'V',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'R',
#   'V',
#   'V',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O',
#   'V',
#   'W',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'N',
#   'C',
#   'A',
#   'C',
#   'M',
#   'V',
#   'C',
#   'D',
#   'M',
#   'O'],
#  ['R',
#   'V',
#   'A',
#   'A',
#   'A',
#   'O',
#   'O',
#   'O',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'O',
#   'C',
#   'D',
#   'N',
#   'O',
#   'V',
#   'D',
#   'N',
#   'V',
#   'C',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'C',
#   'A',
#   'V',
#   'N',
#   'C',
#   'A',
#   'O',
#   'W',
#   'V',
#   'D',
#   'O',
#   'N',
#   'N',
#   'C',
#   'A',
#   'O'],
#  ['A',
#   'W',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'V',
#   'O',
#   'A',
#   'A',
#   'V',
#   'V',
#   'A',
#   'N',
#   'P',
#   'V',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['V',
#   'D',
#   'A',
#   'A',
#   'C',
#   'N',
#   'W',
#   'A',
#   'V',
#   'N',
#   'R',
#   'R',
#   'V',
#   'P',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'O'],
#  ['O',
#   'P',
#   'V',
#   'D',
#   'N',
#   'C',
#   'D',
#   'V',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'R',
#   'V',
#   'R',
#   'C',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'P',
#   'A',
#   'N',
#   'R',
#   'A',
#   'C',
#   'A',
#   'P',
#   'A',
#   'N',
#   'A',
#   'V',
#   'D',
#   'R',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'P',
#   'V',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A', 'V', 'C', 'A', 'N', 'C', 'A', 'N', 'C', 'N', 'C', 'A', 'A', 'N', 'N'],
#  ['R', 'V', 'A', 'N', 'O'],
#  ['V',
#   'A',
#   'N',
#   'M',
#   'V',
#   'O',
#   'A',
#   'C',
#   'N',
#   'C',
#   'N',
#   'O',
#   'C',
#   'V',
#   'D',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'O'],
#  ['A',
#   'A',
#   'O',
#   'V',
#   'C',
#   'D',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'C',
#   'A',
#   'C',
#   'A',
#   'C',
#   'A',
#   'O',
#   'V',
#   'W',
#   'D',
#   'A',
#   'O',
#   'V',
#   'R',
#   'R',
#   'V',
#   'A',
#   'N',
#   'C',
#   'N',
#   'C',
#   'N',
#   'O',
#   'P',
#   'V',
#   'R',
#   'R',
#   'V',
#   'D',
#   'M',
#   'C',
#   'N',
#   'O'],
#  ['A', 'V', 'W', 'P', 'V', 'O', 'R', 'R', 'V', 'D', 'R', 'N', 'O'],
#  ['A',
#   'N',
#   'R',
#   'V',
#   'D',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'W',
#   'P',
#   'V',
#   'V',
#   'C',
#   'A',
#   'O'],
#  ['O'],
#  ['A', 'N', 'V', 'C', 'N', 'M', 'R', 'V', 'A', 'C', 'N', 'O'],
#  ['C',
#   'A',
#   'N',
#   'V',
#   'A',
#   'W',
#   'C',
#   'D',
#   'N',
#   'C',
#   'N',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'A',
#   'O'],
#  ['V', 'P', 'R', 'D', 'N', 'C', 'W', 'O'],
#  ['D', 'V', 'P', 'C', 'D', 'A', 'V', 'A', 'O'],
#  ['V', 'D', 'A', 'N', 'M', 'V', 'D', 'N', 'C', 'D'],
#  ['V', 'V', 'R', 'C', 'N', 'O'],
#  ['D',
#   'V',
#   'P',
#   'V',
#   'D',
#   'V',
#   'N',
#   'C',
#   'A',
#   'C',
#   'V',
#   'A',
#   'N',
#   'C',
#   'A',
#   'A',
#   'D',
#   'N',
#   'C',
#   'V',
#   'N',
#   'O'],
#  ['R',
#   'V',
#   'P',
#   'V',
#   'R',
#   'A',
#   'A',
#   'P',
#   'O',
#   'A',
#   'A',
#   'V',
#   'O',
#   'O',
#   'A',
#   'V',
#   'R',
#   'V',
#   'D',
#   'N'],
#  ['V',
#   'O',
#   'C',
#   'C',
#   'D',
#   'A',
#   'W',
#   'O',
#   'A',
#   'V',
#   'P',
#   'V',
#   'D',
#   'R',
#   'A',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['A', 'A', 'C', 'O', 'A', 'A'],
#  ['V',
#   'C',
#   'C',
#   'P',
#   'C',
#   'O',
#   'N',
#   'C',
#   'N',
#   'C',
#   'A',
#   'N',
#   'V',
#   'P',
#   'N',
#   'R',
#   'V',
#   'R',
#   'O',
#   'A',
#   'O'],
#  ['O'],
#  ['A',
#   'V',
#   'P',
#   'N',
#   'V',
#   'V',
#   'R',
#   'A',
#   'O',
#   'O',
#   'A',
#   'A',
#   'V',
#   'C',
#   'D',
#   'N',
#   'N',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'V',
#   'R',
#   'C',
#   'A',
#   'O',
#   'R',
#   'C',
#   'A',
#   'V',
#   'D',
#   'A',
#   'N',
#   'C',
#   'W',
#   'R',
#   'V',
#   'O'],
#  ['V', 'R', 'V', 'R', 'A', 'O'],
#  ['V', 'R', 'V', 'R', 'A', 'C', 'A', 'O'],
#  ['V', 'V', 'R', 'D', 'N', 'C', 'V', 'N', 'C', 'V', 'N', 'O'],
#  ['O'],
#  ['P',
#   'V',
#   'D',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'A',
#   'O',
#   'A',
#   'A',
#   'R',
#   'V',
#   'D',
#   'V',
#   'C',
#   'N',
#   'C',
#   'V',
#   'N',
#   'R',
#   'N',
#   'C',
#   'N',
#   'N',
#   'O',
#   'A',
#   'C',
#   'A',
#   'O',
#   'O',
#   'N',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'C',
#   'D',
#   'O',
#   'N',
#   'N',
#   'O'],
#  ['A', 'A', 'N', 'N', 'W', 'D', 'A', 'N', 'V', 'V', 'O'],
#  ['P',
#   'A',
#   'W',
#   'V',
#   'R',
#   'V',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['V',
#   'D',
#   'N',
#   'A',
#   'V',
#   'R',
#   'A',
#   'R',
#   'A',
#   'N',
#   'C',
#   'M',
#   'R',
#   'V',
#   'A',
#   'C',
#   'V',
#   'A',
#   'N',
#   'O'],
#  ['P',
#   'N',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O',
#   'O',
#   'N',
#   'W',
#   'A',
#   'R',
#   'D',
#   'A',
#   'N',
#   'C',
#   'N',
#   'O'],
#  ['A',
#   'W',
#   'V',
#   'W',
#   'P',
#   'M',
#   'V',
#   'D',
#   'A',
#   'A',
#   'W',
#   'O',
#   'O',
#   'P',
#   'V',
#   'O',
#   'V',
#   'D',
#   'A',
#   'A',
#   'A',
#   'C',
#   'P',
#   'N',
#   'O'],
#  ['A',
#   'A',
#   'V',
#   'V',
#   'R',
#   'V',
#   'W',
#   'P',
#   'V',
#   'A',
#   'C',
#   'A',
#   'C',
#   'A',
#   'C',
#   'D',
#   'N',
#   'C',
#   'W',
#   'O'],
#  ['O'],
#  ['A',
#   'P',
#   'N',
#   'V',
#   'V',
#   'N',
#   'O',
#   'C',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'C',
#   'W',
#   'R',
#   'P',
#   'N',
#   'V',
#   'C',
#   'A',
#   'N',
#   'R',
#   'D',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['A', 'N', 'C', 'D', 'A', 'N', 'V', 'V', 'V', 'C', 'O', 'N', 'C', 'N', 'O'],
#  ['A', 'V', 'V', 'D', 'O', 'N', 'C', 'A', 'A', 'N'],
#  ['O',
#   'N',
#   'N',
#   'C',
#   'O',
#   'O',
#   'C',
#   'D',
#   'A',
#   'V',
#   'V',
#   'V',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['O',
#   'C',
#   'P',
#   'N',
#   'W',
#   'O',
#   'A',
#   'A',
#   'V',
#   'O',
#   'O',
#   'A',
#   'V',
#   'P',
#   'M',
#   'V',
#   'A',
#   'A',
#   'C',
#   'O',
#   'N',
#   'O'],
#  ['A', 'P', 'V', 'O', 'O', 'A', 'V', 'C', 'V', 'N', 'O'],
#  ['M', 'R', 'V', 'C', 'D', 'N'],
#  ['A', 'R', 'D', 'N', 'C', 'D', 'N', 'O'],
#  ['O'],
#  ['A',
#   'V',
#   'P',
#   'N',
#   'N',
#   'V',
#   'V',
#   'N',
#   'A',
#   'A',
#   'N',
#   'N',
#   'O',
#   'D',
#   'V',
#   'C',
#   'A',
#   'C',
#   'O',
#   'O',
#   'A',
#   'N',
#   'O',
#   'A',
#   'A',
#   'O',
#   'O',
#   'O',
#   'C',
#   'A',
#   'A',
#   'C',
#   'R',
#   'O'],
#  ['A',
#   'O',
#   'A',
#   'P',
#   'A',
#   'N',
#   'N',
#   'O',
#   'N',
#   'O',
#   'V',
#   'P',
#   'A',
#   'A',
#   'A',
#   'A',
#   'N',
#   'V',
#   'V',
#   'A',
#   'N',
#   'C',
#   'N',
#   'A',
#   'O',
#   'C',
#   'A',
#   'A',
#   'N',
#   'W',
#   'N',
#   'R',
#   'O',
#   'V',
#   'A',
#   'O',
#   'W',
#   'D',
#   'A',
#   'N',
#   'V',
#   'R',
#   'V',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'C',
#   'N',
#   'C',
#   'P',
#   'N',
#   'N',
#   'O'],
#  ['A', 'N', 'V', 'A', 'O'],
#  ['M', 'V', 'A', 'O', 'O', 'C', 'O', 'O', 'A', 'A', 'V', 'O'],
#  ['A',
#   'P',
#   'M',
#   'R',
#   'V',
#   'C',
#   'P',
#   'R',
#   'O',
#   'O',
#   'C',
#   'A',
#   'A',
#   'P',
#   'N',
#   'N',
#   'M',
#   'V',
#   'A',
#   'O',
#   'P',
#   'V',
#   'O'],
#  ['A',
#   'O',
#   'P',
#   'M',
#   'C',
#   'R',
#   'V',
#   'D',
#   'N',
#   'O',
#   'C',
#   'D',
#   'N',
#   'O',
#   'C',
#   'D',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['A', 'N', 'V', 'P', 'V', 'N', 'R', 'V', 'O', 'N', 'N', 'O', 'P', 'V', 'O'],
#  ['N',
#   'M',
#   'R',
#   'N',
#   'A',
#   'V',
#   'A',
#   'P',
#   'V',
#   'A',
#   'N',
#   'O',
#   'C',
#   'P',
#   'V',
#   'P',
#   'M',
#   'V',
#   'C',
#   'N',
#   'C',
#   'O',
#   'A',
#   'A',
#   'N',
#   'W',
#   'N'],
#  ['M',
#   'V',
#   'V',
#   'C',
#   'D',
#   'N',
#   'P',
#   'N',
#   'R',
#   'A',
#   'P',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['P',
#   'N',
#   'V',
#   'R',
#   'V',
#   'C',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'A',
#   'O',
#   'O',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'C',
#   'P',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O',
#   'V',
#   'A',
#   'N',
#   'O'],
#  ['V',
#   'A',
#   'N',
#   'N',
#   'O',
#   'V',
#   'C',
#   'A',
#   'N',
#   'O',
#   'V',
#   'R',
#   'V',
#   'R',
#   'V',
#   'O',
#   'O',
#   'O',
#   'O',
#   'V',
#   'P'],
#  ['N', 'P', 'A', 'A', 'N', 'O'],
#  ['N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'A',
#   'N',
#   'M',
#   'V',
#   'A',
#   'R',
#   'V',
#   'C',
#   'O',
#   'N',
#   'C',
#   'N',
#   'C',
#   'O',
#   'O',
#   'C',
#   'C',
#   'D',
#   'O',
#   'N',
#   'C',
#   'O',
#   'C',
#   'O',
#   'O'],
#  ['A',
#   'V',
#   'O',
#   'N',
#   'C',
#   'A',
#   'W',
#   'O',
#   'O',
#   'R',
#   'C',
#   'P',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'O',
#   'W',
#   'D',
#   'N',
#   'V',
#   'C',
#   'O',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'R',
#   'V',
#   'D',
#   'V',
#   'C',
#   'D',
#   'N',
#   'R',
#   'A',
#   'D',
#   'N',
#   'C',
#   'N',
#   'O',
#   'O',
#   'A',
#   'A',
#   'V',
#   'O',
#   'C',
#   'A',
#   'A',
#   'V',
#   'R',
#   'V',
#   'C',
#   'P',
#   'O'],
#  ['A',
#   'V',
#   'D',
#   'A',
#   'W',
#   'C',
#   'P',
#   'N',
#   'N',
#   'O',
#   'O',
#   'P',
#   'V',
#   'O',
#   'V',
#   'W',
#   'A',
#   'A',
#   'V',
#   'R',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O',
#   'C',
#   'P',
#   'M',
#   'V',
#   'A',
#   'O'],
#  ['A',
#   'V',
#   'R',
#   'R',
#   'C',
#   'V',
#   'N',
#   'N',
#   'N',
#   'C',
#   'A',
#   'O',
#   'C',
#   'N',
#   'C',
#   'D',
#   'N',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'R',
#   'V',
#   'C',
#   'D',
#   'N',
#   'W',
#   'N',
#   'C',
#   'A',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'N',
#   'N',
#   'O',
#   'A',
#   'N',
#   'C',
#   'A',
#   'V',
#   'O',
#   'C',
#   'A',
#   'A',
#   'O',
#   'A',
#   'O',
#   'D',
#   'A',
#   'A',
#   'N',
#   'N',
#   'C',
#   'N',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'A',
#   'V',
#   'V',
#   'N',
#   'A',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'C',
#   'V',
#   'C',
#   'O',
#   'A',
#   'C',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'C',
#   'O',
#   'O',
#   'O',
#   'R',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['N', 'N', 'P', 'A', 'N', 'M', 'V', 'C', 'D', 'N', 'C', 'D', 'N', 'O'],
#  ['N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'V',
#   'V',
#   'R',
#   'N',
#   'A',
#   'A',
#   'A',
#   'N',
#   'C',
#   'P',
#   'V',
#   'C',
#   'D',
#   'A',
#   'N'],
#  ['N', 'R', 'O', 'R', 'V', 'V', 'N', 'N', 'C', 'N', 'N', 'O'],
#  ['N',
#   'N',
#   'M',
#   'V',
#   'D',
#   'N',
#   'O',
#   'C',
#   'N',
#   'V',
#   'A',
#   'R',
#   'V',
#   'A',
#   'O',
#   'N',
#   'N',
#   'C',
#   'N',
#   'V',
#   'O',
#   'V',
#   'N',
#   'W',
#   'N',
#   'M',
#   'A',
#   'P',
#   'A',
#   'N',
#   'O'],
#  ['N',
#   'V',
#   'O',
#   'V',
#   'D',
#   'M',
#   'R',
#   'C',
#   'N',
#   'C',
#   'R',
#   'C',
#   'N',
#   'C',
#   'W',
#   'O',
#   'O',
#   'A',
#   'A',
#   'O',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O',
#   'V',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'M',
#   'R',
#   'N',
#   'A',
#   'C',
#   'A',
#   'N',
#   'N',
#   'O',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'O',
#   'P',
#   'V',
#   'O'],
#  ['V', 'R', 'V', 'A', 'P', 'N', 'O'],
#  ['N',
#   'N',
#   'V',
#   'N',
#   'M',
#   'V',
#   'C',
#   'D',
#   'N',
#   'A',
#   'C',
#   'A',
#   'N',
#   'N',
#   'C',
#   'M',
#   'R',
#   'N',
#   'D',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['O',
#   'R',
#   'O',
#   'A',
#   'N',
#   'V',
#   'O',
#   'M',
#   'N',
#   'A',
#   'O',
#   'A',
#   'A',
#   'C',
#   'A',
#   'A',
#   'O'],
#  ['V',
#   'W',
#   'V',
#   'R',
#   'D',
#   'N',
#   'C',
#   'A',
#   'O',
#   'D',
#   'A',
#   'N',
#   'N',
#   'V',
#   'C',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['V', 'V', 'O', 'N', 'C', 'A', 'R', 'C', 'O', 'N'],
#  ['N', 'O'],
#  ['N',
#   'R',
#   'A',
#   'V',
#   'C',
#   'O',
#   'N',
#   'O',
#   'A',
#   'C',
#   'C',
#   'O',
#   'N',
#   'A',
#   'A',
#   'O'],
#  ['A', 'N', 'C', 'D', 'N', 'N', 'W', 'V', 'A', 'O'],
#  ['C',
#   'A',
#   'O',
#   'N',
#   'V',
#   'V',
#   'C',
#   'D',
#   'V',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'V',
#   'N',
#   'O'],
#  ['V', 'N', 'A', 'O'],
#  ['O',
#   'R',
#   'V',
#   'N',
#   'V',
#   'C',
#   'D',
#   'N',
#   'O',
#   'C',
#   'D',
#   'N',
#   'V',
#   'A',
#   'O',
#   'C',
#   'A',
#   'A',
#   'N',
#   'V',
#   'A',
#   'O'],
#  ['N', 'C', 'N', 'V', 'A', 'O'],
#  ['A',
#   'N',
#   'V',
#   'R',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'C',
#   'R',
#   'R',
#   'R',
#   'A',
#   'D',
#   'N',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'D',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['N',
#   'W',
#   'V',
#   'A',
#   'R',
#   'R',
#   'V',
#   'C',
#   'D',
#   'A',
#   'N',
#   'V',
#   'N',
#   'C',
#   'A',
#   'C',
#   'A'],
#  ['V', 'R', 'A', 'O'],
#  ['A', 'N', 'V', 'N', 'N', 'R', 'C', 'W', 'N', 'O'],
#  ['N',
#   'O',
#   'A',
#   'N',
#   'N',
#   'V',
#   'R',
#   'D',
#   'C',
#   'D',
#   'N',
#   'R',
#   'O',
#   'R',
#   'A',
#   'N',
#   'O'],
#  ['V',
#   'N',
#   'V',
#   'R',
#   'C',
#   'A',
#   'O',
#   'C',
#   'A',
#   'N',
#   'N',
#   'V',
#   'N',
#   'N',
#   'M',
#   'V',
#   'D',
#   'N',
#   'O',
#   'C',
#   'R',
#   'R',
#   'R',
#   'D',
#   'N',
#   'C',
#   'O',
#   'P',
#   'A',
#   'N',
#   'O'],
#  ['D', 'O', 'A', 'D', 'O', 'A', 'N', 'V', 'N', 'N', 'C', 'N', 'N', 'O'],
#  ['N', 'N', 'M', 'V', 'R', 'R', 'V', 'D', 'A', 'A', 'N', 'C', 'N', 'P', 'N'],
#  ['N', 'O'],
#  ['O', 'W', 'R', 'O', 'O'],
#  ['N',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'D',
#   'N',
#   'R',
#   'O',
#   'V',
#   'V',
#   'R',
#   'C',
#   'A',
#   'N',
#   'P',
#   'N',
#   'O'],
#  ['V',
#   'V',
#   'A',
#   'A',
#   'C',
#   'V',
#   'O',
#   'C',
#   'P',
#   'R',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['N', 'M', 'V', 'A', 'N', 'N'],
#  ['N', 'O', 'O', 'V', 'A', 'A', 'O', 'D', 'N', 'C', 'A', 'A', 'O'],
#  ['M',
#   'V',
#   'C',
#   'R',
#   'A',
#   'N',
#   'N',
#   'O',
#   'R',
#   'V',
#   'C',
#   'A',
#   'N',
#   'W',
#   'N',
#   'N',
#   'R',
#   'V',
#   'R',
#   'C',
#   'O',
#   'O'],
#  ['N', 'C', 'D', 'A', 'N', 'O'],
#  ['N', 'N', 'V', 'V', 'A', 'C', 'V', 'O', 'A', 'N', 'N', 'V', 'V', 'A', 'O'],
#  ['D',
#   'A',
#   'N',
#   'O',
#   'P',
#   'V',
#   'C',
#   'O',
#   'N',
#   'A',
#   'C',
#   'P',
#   'V',
#   'C',
#   'O',
#   'O'],
#  ['A', 'N', 'V', 'N', 'O'],
#  ['N', 'V', 'A', 'C', 'D', 'N', 'N', 'C', 'N'],
#  ['V',
#   'N',
#   'R',
#   'A',
#   'A',
#   'A',
#   'N',
#   'R',
#   'V',
#   'V',
#   'A',
#   'N',
#   'C',
#   'N',
#   'A',
#   'V',
#   'O'],
#  ['N', 'O', 'C', 'D', 'A', 'N', 'O', 'V', 'A', 'N', 'C', 'A', 'O'],
#  ['A',
#   'V',
#   'V',
#   'R',
#   'A',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'N',
#   'N',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'A',
#   'P',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'N',
#   'N',
#   'V',
#   'R',
#   'V',
#   'R',
#   'V',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'V',
#   'V',
#   'O'],
#  ['O'],
#  ['C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'A',
#   'N',
#   'N',
#   'V',
#   'R',
#   'C',
#   'O',
#   'N',
#   'R',
#   'O',
#   'N',
#   'A',
#   'C',
#   'D',
#   'N',
#   'R',
#   'O'],
#  ['N',
#   'O',
#   'A',
#   'N',
#   'R',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'V',
#   'V',
#   'C',
#   'D',
#   'N',
#   'N',
#   'C',
#   'C',
#   'O',
#   'A'],
#  ['O', 'A', 'N', 'O', 'R', 'O', 'N', 'C', 'O', 'A'],
#  ['O', 'A', 'N'],
#  ['N', 'R', 'O'],
#  ['D',
#   'A',
#   'A',
#   'V',
#   'C',
#   'A',
#   'C',
#   'A',
#   'A',
#   'O',
#   'A',
#   'A',
#   'C',
#   'A',
#   'N',
#   'M',
#   'V',
#   'D',
#   'N',
#   'N',
#   'N',
#   'O',
#   'D',
#   'A',
#   'R',
#   'R',
#   'D',
#   'N',
#   'V',
#   'O'],
#  ['C',
#   'D',
#   'N',
#   'N',
#   'M',
#   'V',
#   'A',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'P',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'C',
#   'N',
#   'C',
#   'D',
#   'N',
#   'N',
#   'O'],
#  ['D', 'A', 'A', 'N', 'C', 'V', 'A', 'O', 'W'],
#  ['N',
#   'V',
#   'D',
#   'A',
#   'A',
#   'A',
#   'N',
#   'R',
#   'V',
#   'A',
#   'A',
#   'O',
#   'V',
#   'V',
#   'D',
#   'A',
#   'C',
#   'A',
#   'N',
#   'N',
#   'C',
#   'N',
#   'O'],
#  ['N',
#   'O',
#   'A',
#   'P',
#   'A',
#   'N',
#   'O',
#   'A',
#   'A',
#   'A',
#   'O',
#   'V',
#   'P',
#   'V',
#   'V',
#   'V',
#   'C',
#   'O',
#   'C',
#   'A',
#   'A',
#   'N',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'A',
#   'O',
#   'A',
#   'A',
#   'N',
#   'C',
#   'A',
#   'P',
#   'A',
#   'A',
#   'A',
#   'A',
#   'N',
#   'N',
#   'O',
#   'V',
#   'P',
#   'V',
#   'V',
#   'R',
#   'V',
#   'D',
#   'N',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'C',
#   'V',
#   'V',
#   'C',
#   'A',
#   'A',
#   'O'],
#  ['A', 'V', 'P', 'M', 'R', 'V', 'D', 'A', 'N', 'O'],
#  ['A',
#   'R',
#   'R',
#   'A',
#   'C',
#   'A',
#   'V',
#   'W',
#   'O',
#   'C',
#   'D',
#   'N',
#   'V',
#   'R',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'O',
#   'D',
#   'A',
#   'N'],
#  ['W'],
#  ['V',
#   'P',
#   'M',
#   'R',
#   'V',
#   'O',
#   'P',
#   'M',
#   'V',
#   'D',
#   'N',
#   'C',
#   'R',
#   'V',
#   'P',
#   'R',
#   'N',
#   'O'],
#  ['O', 'R', 'O', 'P', 'M', 'R', 'V', 'R', 'O', 'C', 'D', 'N', 'C', 'N', 'O'],
#  ['A',
#   'V',
#   'D',
#   'N',
#   'M',
#   'V',
#   'V',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'W',
#   'N',
#   'V',
#   'A',
#   'A',
#   'C',
#   'W',
#   'A',
#   'A',
#   'N',
#   'V',
#   'V',
#   'R',
#   'V',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'V',
#   'R',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'C',
#   'V',
#   'D',
#   'C',
#   'D',
#   'A',
#   'V',
#   'C',
#   'A',
#   'P',
#   'A',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'R',
#   'N',
#   'D',
#   'N',
#   'O',
#   'C',
#   'N',
#   'N',
#   'V',
#   'V',
#   'N',
#   'M',
#   'V',
#   'R',
#   'C',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['A',
#   'V',
#   'N',
#   'W',
#   'A',
#   'V',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'N',
#   'R',
#   'R',
#   'A',
#   'R',
#   'D',
#   'N',
#   'R',
#   'R',
#   'W',
#   'D',
#   'N',
#   'M',
#   'V',
#   'D',
#   'N',
#   'O'],
#  ['N',
#   'A',
#   'A',
#   'C',
#   'N',
#   'N',
#   'A',
#   'D',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'O',
#   'A',
#   'A',
#   'O',
#   'W',
#   'V',
#   'A',
#   'C',
#   'V',
#   'D',
#   'N',
#   'C',
#   'P',
#   'N',
#   'C',
#   'A',
#   'O',
#   'O'],
#  ['A',
#   'O',
#   'R',
#   'A',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'N',
#   'A',
#   'A',
#   'A',
#   'O',
#   'V',
#   'D',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'O',
#   'C',
#   'M',
#   'V',
#   'V',
#   'R',
#   'C',
#   'A',
#   'A',
#   'P',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['C',
#   'D',
#   'N',
#   'W',
#   'A',
#   'A',
#   'V',
#   'V',
#   'V',
#   'R',
#   'A',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'D',
#   'A',
#   'V',
#   'O',
#   'O',
#   'A',
#   'V',
#   'R',
#   'D',
#   'N',
#   'A',
#   'V',
#   'V',
#   'V',
#   'C',
#   'O'],
#  ['V', 'V', 'C', 'R', 'V', 'C', 'D', 'N', 'O'],
#  ['O'],
#  ['O',
#   'A',
#   'A',
#   'N',
#   'N',
#   'V',
#   'P',
#   'V',
#   'D',
#   'N',
#   'P',
#   'N',
#   'N',
#   'M',
#   'V',
#   'A',
#   'V',
#   'C',
#   'P',
#   'O'],
#  ['A'],
#  ['R',
#   'V',
#   'D',
#   'N',
#   'C',
#   'P',
#   'O',
#   'C',
#   'V',
#   'P',
#   'V',
#   'P',
#   'R',
#   'O',
#   'O',
#   'V',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O',
#   'D',
#   'A',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'O',
#   'N',
#   'C',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O',
#   'D',
#   'A',
#   'C',
#   'A',
#   'A',
#   'N',
#   'O',
#   'V',
#   'O',
#   'O',
#   'A',
#   'V',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'C',
#   'P',
#   'V',
#   'R',
#   'V',
#   'W',
#   'V'],
#  ['P', 'V', 'R', 'V', 'C', 'O'],
#  ['V', 'R', 'V', 'R', 'V', 'N', 'C', 'C', 'D', 'V', 'C', 'A', 'O'],
#  ['O'],
#  ['C',
#   'A',
#   'A',
#   'N',
#   'A',
#   'A',
#   'O',
#   'C',
#   'R',
#   'C',
#   'C',
#   'A',
#   'N',
#   'A',
#   'A',
#   'A',
#   'O',
#   'R',
#   'V',
#   'P',
#   'V',
#   'D',
#   'N',
#   'O'],
#  ['C', 'A', 'A', 'A', 'O', 'D', 'A', 'A', 'N'],
#  ['V', 'V', 'P', 'N', 'O', 'V', 'V', 'O'],
#  ['A',
#   'V',
#   'V',
#   'W',
#   'A',
#   'V',
#   'V',
#   'R',
#   'N',
#   'R',
#   'D',
#   'N',
#   'N',
#   'C',
#   'N',
#   'O',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'R',
#   'O',
#   'V',
#   'C',
#   'P',
#   'O'],
#  ['A', 'O', 'O'],
#  ['A',
#   'O',
#   'A',
#   'P',
#   'A',
#   'A',
#   'A',
#   'V',
#   'P',
#   'O',
#   'O',
#   'O',
#   'R',
#   'O',
#   'O',
#   'O',
#   'N',
#   'R',
#   'D',
#   'A',
#   'A',
#   'N',
#   'C',
#   'A',
#   'A',
#   'P',
#   'A',
#   'N',
#   'O'],
#  ['N',
#   'V',
#   'R',
#   'V',
#   'C',
#   'A',
#   'O',
#   'A',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O',
#   'D',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'O',
#   'A',
#   'A',
#   'A',
#   'A',
#   'V',
#   'V',
#   'P',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'A',
#   'O',
#   'A',
#   'O',
#   'A',
#   'O',
#   'A',
#   'O'],
#  ['N',
#   'V',
#   'A',
#   'C',
#   'O',
#   'O',
#   'O',
#   'C',
#   'O',
#   'O',
#   'V',
#   'R',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'O',
#   'A',
#   'V',
#   'O',
#   'A',
#   'C',
#   'A',
#   'A',
#   'C',
#   'C',
#   'O',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'V',
#   'R',
#   'A',
#   'C',
#   'A',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O',
#   'A',
#   'O',
#   'R',
#   'N',
#   'C',
#   'N',
#   'N',
#   'O'],
#  ['N',
#   'V',
#   'V',
#   'W',
#   'P',
#   'A',
#   'A',
#   'N',
#   'R',
#   'V',
#   'D',
#   'A',
#   'A',
#   'A',
#   'N',
#   'N',
#   'C',
#   'O',
#   'O'],
#  ['N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'P',
#   'N',
#   'V',
#   'A',
#   'N',
#   'V',
#   'O',
#   'R',
#   'V',
#   'O',
#   'C',
#   'D',
#   'A',
#   'O',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'A',
#   'A',
#   'A',
#   'O',
#   'A',
#   'A',
#   'N',
#   'N',
#   'O',
#   'C',
#   'A',
#   'N',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'O',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'A',
#   'V',
#   'R',
#   'V',
#   'D',
#   'A',
#   'N',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'A',
#   'O',
#   'C',
#   'D',
#   'A',
#   'N',
#   'M',
#   'V',
#   'V',
#   'O',
#   'M',
#   'V',
#   'V',
#   'C',
#   'A',
#   'C',
#   'V',
#   'O',
#   'N',
#   'V',
#   'C',
#   'A',
#   'C',
#   'O',
#   'N',
#   'V',
#   'C',
#   'A',
#   'O'],
#  ['R', 'V', 'A', 'A', 'A', 'A', 'O', 'W', 'N', 'P', 'A', 'N', 'O'],
#  ['V',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'A',
#   'C',
#   'A',
#   'N',
#   'C',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'A',
#   'V',
#   'P',
#   'V',
#   'D',
#   'N',
#   'P',
#   'N',
#   'N',
#   'C',
#   'W',
#   'N',
#   'R',
#   'N',
#   'N',
#   'C',
#   'A',
#   'N',
#   'M',
#   'V',
#   'V',
#   'C',
#   'D',
#   'N',
#   'R',
#   'N',
#   'C',
#   'N',
#   'C',
#   'C',
#   'A',
#   'O',
#   'O'],
#  ['N',
#   'V',
#   'D',
#   'N',
#   'V',
#   'R',
#   'V',
#   'C',
#   'N',
#   'R',
#   'D',
#   'V',
#   'V',
#   'C',
#   'A',
#   'O',
#   'D',
#   'N',
#   'C',
#   'W',
#   'C',
#   'N',
#   'N',
#   'O'],
#  ['N',
#   'V',
#   'N',
#   'R',
#   'N',
#   'A',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'N',
#   'V',
#   'A',
#   'C',
#   'O',
#   'N',
#   'C',
#   'D',
#   'N',
#   'P',
#   'A',
#   'N',
#   'C',
#   'A',
#   'D',
#   'N',
#   'N',
#   'O'],
#  ['P',
#   'A',
#   'N',
#   'N',
#   'V',
#   'O',
#   'N',
#   'C',
#   'A',
#   'C',
#   'A',
#   'C',
#   'V',
#   'R',
#   'O',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'D',
#   'A',
#   'A',
#   'A',
#   'V',
#   'O'],
#  ['N',
#   'C',
#   'W',
#   'N',
#   'V',
#   'V',
#   'R',
#   'C',
#   'P',
#   'A',
#   'A',
#   'C',
#   'O',
#   'O',
#   'N',
#   'N',
#   'V',
#   'A',
#   'A',
#   'O'],
#  ['P', 'V', 'A', 'R', 'V', 'W', 'N', 'C', 'N', 'R', 'V', 'O', 'N', 'V', 'O'],
#  ['O', 'N', 'O', 'R', 'C', 'A', 'N', 'A', 'A', 'N', 'N'],
#  ['N',
#   'C',
#   'A',
#   'O',
#   'A',
#   'N',
#   'N',
#   'V',
#   'A',
#   'R',
#   'N',
#   'N',
#   'R',
#   'C',
#   'O',
#   'O',
#   'D',
#   'N',
#   'V',
#   'O'],
#  ['C',
#   'N',
#   'V',
#   'R',
#   'V',
#   'R',
#   'C',
#   'A',
#   'C',
#   'D',
#   'A',
#   'A',
#   'P',
#   'A',
#   'N',
#   'O',
#   'N',
#   'C',
#   'D',
#   'N',
#   'R',
#   'V',
#   'V',
#   'M',
#   'V',
#   'V',
#   'O',
#   'R',
#   'A',
#   'N',
#   'O'],
#  ['V',
#   'N',
#   'V',
#   'N',
#   'W',
#   'D',
#   'A',
#   'N',
#   'M',
#   'N',
#   'A',
#   'V',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'A',
#   'O',
#   'O',
#   'N',
#   'C',
#   'A',
#   'N',
#   'R',
#   'V',
#   'V',
#   'C',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O',
#   'C',
#   'D',
#   'N',
#   'N',
#   'R',
#   'V',
#   'V',
#   'V',
#   'A',
#   'O',
#   'V',
#   'V',
#   'R',
#   'N',
#   'R',
#   'A',
#   'O',
#   'A',
#   'O'],
#  ['M', 'V', 'D', 'A', 'N', 'C', 'D', 'A', 'O', 'O'],
#  ['V', 'A', 'O', 'A', 'C', 'A', 'O', 'C', 'D', 'N', 'O'],
#  ['N',
#   'R',
#   'A',
#   'A',
#   'N',
#   'O',
#   'A',
#   'A',
#   'A',
#   'A',
#   'A',
#   'N',
#   'V',
#   'D',
#   'A',
#   'N',
#   'M',
#   'R',
#   'V',
#   'D',
#   'N',
#   'C',
#   'N',
#   'N',
#   'M',
#   'N',
#   'C',
#   'N',
#   'C',
#   'A',
#   'N',
#   'C',
#   'R',
#   'V',
#   'C',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['N',
#   'N',
#   'W',
#   'D',
#   'A',
#   'N',
#   'M',
#   'V',
#   'N',
#   'A',
#   'N',
#   'C',
#   'C',
#   'O',
#   'O',
#   'A',
#   'O'],
#  ['R',
#   'N',
#   'N',
#   'C',
#   'A',
#   'N',
#   'C',
#   'R',
#   'C',
#   'O',
#   'O',
#   'A',
#   'O',
#   'V',
#   'C',
#   'D',
#   'N',
#   'P',
#   'V',
#   'A',
#   'O',
#   'C',
#   'D',
#   'A',
#   'A',
#   'O',
#   'C',
#   'O',
#   'O'],
#  ['D',
#   'A',
#   'N',
#   'C',
#   'N',
#   'C',
#   'D',
#   'N',
#   'N',
#   'R',
#   'V',
#   'V',
#   'M',
#   'R',
#   'V',
#   'V',
#   'C',
#   'D',
#   'A'],
#  ['C', 'A', 'N', 'O'],
#  ['R',
#   'O',
#   'A',
#   'N',
#   'V',
#   'A',
#   'R',
#   'V',
#   'N',
#   'C',
#   'D',
#   'O',
#   'A',
#   'N',
#   'O',
#   'N',
#   'V',
#   'O'],
#  ['D', 'A', 'A', 'C', 'A', 'A', 'O', 'N', 'C', 'A', 'N', 'V', 'C', 'O', 'A'],
#  ['N', 'O', 'A', 'O'],
#  ['N',
#   'C',
#   'A',
#   'O',
#   'A',
#   'N',
#   'A',
#   'N',
#   'M',
#   'V',
#   'D',
#   'N',
#   'N',
#   'N',
#   'A',
#   'R',
#   'D',
#   'A',
#   'V',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'D',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'C',
#   'A',
#   'O'],
#  ['D', 'N', 'M', 'N', 'A', 'O', 'C', 'V', 'V', 'C', 'D', 'N'],
#  ['V', 'C', 'W', 'N', 'N', 'D', 'N', 'C', 'D', 'A', 'A', 'C', 'A', 'O'],
#  ['A', 'O', 'D', 'A', 'V', 'A', 'A', 'A', 'O'],
#  ['R', 'V', 'N', 'N', 'A', 'R', 'C', 'O', 'O', 'A', 'C', 'N', 'O'],
#  ['N',
#   'V',
#   'P',
#   'V',
#   'W',
#   'D',
#   'N',
#   'M',
#   'R',
#   'V',
#   'A',
#   'R',
#   'V',
#   'R',
#   'N',
#   'R',
#   'V',
#   'C',
#   'M',
#   'V',
#   'R',
#   'N',
#   'C',
#   'P',
#   'A',
#   'N',
#   'R',
#   'D',
#   'A',
#   'N',
#   'O',
#   'W',
#   'V',
#   'V',
#   'N',
#   'R',
#   'V',
#   'P',
#   'N',
#   'O'],
#  ['V', 'V', 'P', 'V', 'V', 'R', 'V', 'D', 'N', 'N', 'N', 'O'],
#  ['A',
#   'O',
#   'A',
#   'N',
#   'C',
#   'A',
#   'W',
#   'C',
#   'D',
#   'A',
#   'A',
#   'C',
#   'C',
#   'A',
#   'N',
#   'C',
#   'A',
#   'C',
#   'A',
#   'V',
#   'V',
#   'R',
#   'V',
#   'D',
#   'V',
#   'C',
#   'D',
#   'N',
#   'P',
#   'N',
#   'N',
#   'N',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'D',
#   'N',
#   'N',
#   'C',
#   'N',
#   'C',
#   'A',
#   'A',
#   'C',
#   'A',
#   'O'],
#  ['N',
#   'O',
#   'C',
#   'D',
#   'A',
#   'A',
#   'O',
#   'O',
#   'N',
#   'C',
#   'A',
#   'C',
#   'D',
#   'A',
#   'V',
#   'A',
#   'C',
#   'A',
#   'O'],
#  ['N', 'A', 'R', 'C', 'O', 'N', 'C', 'A', 'W', 'C', 'A', 'O', 'P', 'V', 'O'],
#  ['A',
#   'A',
#   'V',
#   'R',
#   'V',
#   'D',
#   'A',
#   'N',
#   'C',
#   'P',
#   'N',
#   'N',
#   'V',
#   'O',
#   'C',
#   'A',
#   'N',
#   'V',
#   'A',
#   'R',
#   'N',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'O',
#   'R',
#   'V',
#   'N',
#   'O'],
#  ['A',
#   'N',
#   'M',
#   'R',
#   'A',
#   'R',
#   'C',
#   'A',
#   'N',
#   'O',
#   'C',
#   'V',
#   'N',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'N',
#   'N',
#   'O',
#   'N',
#   'O',
#   'C',
#   'A',
#   'A',
#   'C',
#   'A',
#   'O'],
#  ['R', 'R', 'A', 'N', 'N'],
#  ['N', 'O'],
#  ['A'],
#  ['M', 'V', 'V', 'R', 'V', 'W', 'A', 'C', 'W', 'R', 'D', 'N', 'N'],
#  ['V', 'N', 'M', 'V', 'O'],
#  ['A',
#   'O',
#   'C',
#   'D',
#   'R',
#   'C',
#   'N',
#   'O',
#   'D',
#   'N',
#   'V',
#   'W',
#   'M',
#   'R',
#   'V',
#   'V',
#   'D',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['V',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'N',
#   'O',
#   'C',
#   'O',
#   'O',
#   'A',
#   'W',
#   'O',
#   'V',
#   'C',
#   'A',
#   'O',
#   'W',
#   'A',
#   'N',
#   'O'],
#  ['O',
#   'C',
#   'V',
#   'O',
#   'A',
#   'V',
#   'C',
#   'D',
#   'N',
#   'N',
#   'R',
#   'V',
#   'R',
#   'C',
#   'R',
#   'V',
#   'D',
#   'N',
#   'N',
#   'C',
#   'P',
#   'A',
#   'V',
#   'R',
#   'C',
#   'O',
#   'A'],
#  ['N', 'C', 'C', 'O', 'W', 'O'],
#  ['P', 'A', 'V', 'C', 'N', 'N', 'A', 'W'],
#  ['N'],
#  ['A',
#   'N',
#   'M',
#   'V',
#   'V',
#   'C',
#   'V',
#   'D',
#   'A',
#   'N',
#   'A',
#   'N',
#   'R',
#   'C',
#   'A',
# ...
#   'D',
#   'A',
#   'P',
#   'N',
#   'O'],
#  ['A',
#   'N',
#   'O',
#   'N',
#   'C',
#   'N',
#   'C',
#   'O',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'P',
#   'C',
#   'D',
#   'A',
#   'O',
#   'V',
#   'O',
#   'O',
#   'A',
#   'V',
#   'V',
#   'W',
#   'V',
#   'N',
#   'C',
#   'A',
#   'P',
#   'C',
#   'A',
#   'A',
#   'V',
#   'R',
#   'A',
#   'R',
#   'P',
#   'O',
#   'C',
#   'P',
#   'V',
#   'R',
#   'A',
#   'R',
#   'V',
#   'A',
#   'N',
#   'R',
#   'D',
#   'A',
#   'P',
#   'N',
#   'O'],
#  ['V',
#   'D',
#   'N',
#   'R',
#   'V',
#   'A',
#   'A',
#   'C',
#   'N',
#   'C',
#   'A',
#   'P',
#   'A',
#   'C',
#   'D',
#   'A',
#   'P',
#   'N',
#   'O'],
#  ['O'],
#  ['N',
#   'V',
#   'P',
#   'M',
#   'V',
#   'O',
#   'C',
#   'A',
#   'N',
#   'O',
#   'A',
#   'W',
#   'N',
#   'C',
#   'A',
#   'D',
#   'A',
#   'N',
#   'V',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'O'],
#  ['A',
#   'O',
#   'A',
#   'A',
#   'O',
#   'D',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'O',
#   'V',
#   'O',
#   'O',
#   'A',
#   'V',
#   'R',
#   'V',
#   'D',
#   'A',
#   'C',
#   'N',
#   'M',
#   'V',
#   'D',
#   'V',
#   'N',
#   'C',
#   'R',
#   'V',
#   'C',
#   'V',
#   'A',
#   'N',
#   'C',
#   'P',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['O'],
#  ['A', 'A'],
#  ['A', 'P', 'A', 'C', 'O', 'A', 'A', 'A', 'O'],
#  ['C',
#   'N',
#   'O',
#   'A',
#   'A',
#   'W',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O',
#   'V',
#   'D',
#   'A',
#   'N',
#   'D',
#   'A',
#   'W',
#   'C',
#   'P',
#   'V',
#   'R',
#   'A',
#   'A',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['C', 'D', 'M', 'V', 'V', 'C', 'A', 'O', 'N', 'C', 'N', 'O'],
#  ['A',
#   'A',
#   'O',
#   'V',
#   'R',
#   'N',
#   'C',
#   'A',
#   'C',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'C',
#   'A',
#   'R',
#   'A',
#   'D',
#   'N',
#   'O',
#   'V',
#   'A',
#   'C',
#   'N',
#   'C',
#   'A',
#   'A',
#   'V',
#   'C',
#   'V',
#   'O'],
#  ['W',
#   'O',
#   'V',
#   'A',
#   'N',
#   'C',
#   'A',
#   'C',
#   'A',
#   'O',
#   'V',
#   'V',
#   'C',
#   'A',
#   'P',
#   'A',
#   'A',
#   'C',
#   'D',
#   'A',
#   'O'],
#  ['O', 'V', 'D', 'A', 'A', 'N', 'C', 'D', 'A', 'O', 'V', 'C', 'N', 'O'],
#  ['P', 'N', 'C', 'D', 'A', 'A', 'N', 'V', 'R', 'V', 'O'],
#  ['A',
#   'A',
#   'V',
#   'W',
#   'N',
#   'C',
#   'N',
#   'C',
#   'N',
#   'V',
#   'R',
#   'V',
#   'A',
#   'N',
#   'C',
#   'D',
#   'N',
#   'V',
#   'A',
#   'R',
#   'C',
#   'W',
#   'C',
#   'W',
#   'A',
#   'O',
#   'C',
#   'N',
#   'N',
#   'V',
#   'A',
#   'C',
#   'C',
#   'D',
#   'N',
#   'C',
#   'N',
#   'C',
#   'N',
#   'R',
#   'V',
#   'D',
#   'N',
#   'O'],
#  ['C', 'W', 'V', 'V', 'O', 'C', 'A', 'A', 'V', 'C', 'O', 'A', 'N', 'O'],
#  ['O'],
#  ['V',
#   'O',
#   'M',
#   'V',
#   'O',
#   'N',
#   'C',
#   'N',
#   'O',
#   'C',
#   'D',
#   'N',
#   'R',
#   'V',
#   'A',
#   'N',
#   'C',
#   'N',
#   'C',
#   'A',
#   'N'],
#  ['V', 'A', 'C', 'N', 'C', 'N', 'O'],
#  ['V', 'P', 'N', 'R', 'A', 'N', 'O', 'C', 'V', 'V', 'C', 'D', 'N', 'O'],
#  ['N',
#   'O',
#   'C',
#   'D',
#   'N',
#   'N',
#   'A',
#   'O',
#   'R',
#   'V',
#   'D',
#   'V',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'P',
#   'A',
#   'O'],
#  ['A',
#   'A',
#   'V',
#   'A',
#   'V',
#   'R',
#   'D',
#   'R',
#   'R',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'P',
#   'N',
#   'O'],
#  ['N',
#   'P',
#   'N',
#   'V',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'V',
#   'D',
#   'A',
#   'A',
#   'R',
#   'V',
#   'N',
#   'A',
#   'A',
#   'R',
#   'V',
#   'N',
#   'O'],
#  ['C',
#   'D',
#   'N',
#   'P',
#   'M',
#   'O',
#   'R',
#   'O',
#   'V',
#   'C',
#   'D',
#   'M',
#   'R',
#   'V',
#   'N',
#   'R',
#   'V',
#   'N',
#   'O'],
#  ['A',
#   'A',
#   'V',
#   'W',
#   'D',
#   'A',
#   'V',
#   'V',
#   'V',
#   'D',
#   'N',
#   'R',
#   'V',
#   'A',
#   'A',
#   'A',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['C',
#   'A',
#   'A',
#   'V',
#   'A',
#   'W',
#   'D',
#   'A',
#   'N',
#   'M',
#   'R',
#   'V',
#   'A',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'D',
#   'N',
#   'N',
#   'A',
#   'A',
#   'C',
#   'V',
#   'N',
#   'V',
#   'D',
#   'A',
#   'A',
#   'C',
#   'D',
#   'N',
#   'C',
#   'C',
#   'D',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['N', 'V', 'V', 'O'],
#  ['W',
#   'P',
#   'O',
#   'A',
#   'V',
#   'R',
#   'A',
#   'D',
#   'A',
#   'N',
#   'N',
#   'C',
#   'D',
#   'N',
#   'N',
#   'R',
#   'A',
#   'O'],
#  ['A', 'P', 'A', 'A', 'V', 'R', 'D', 'A', 'C', 'D', 'A', 'V'],
#  ['V', 'V', 'R', 'V', 'C', 'N', 'C', 'A', 'C', 'A', 'O'],
#  ['O',
#   'W',
#   'V',
#   'V',
#   'V',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O',
#   'V',
#   'R',
#   'V',
#   'C',
#   'A',
#   'N',
#   'C',
#   'V',
#   'R',
#   'V',
#   'D',
#   'A',
#   'N',
#   'C',
#   'A',
#   'C',
#   'A',
#   'O'],
#  ['P',
#   'A',
#   'N',
#   'V',
#   'R',
#   'A',
#   'D',
#   'N',
#   'C',
#   'O',
#   'A',
#   'C',
#   'A',
#   'W',
#   'O',
#   'C',
#   'A',
#   'A',
#   'N',
#   'O',
#   'W'],
#  ['V', 'A', 'O'],
#  ['N',
#   'O',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O',
#   'V',
#   'W',
#   'D',
#   'M',
#   'V',
#   'C',
#   'A',
#   'A',
#   'N',
#   'C',
#   'A',
#   'V',
#   'A',
#   'O'],
#  ['C',
#   'A',
#   'A',
#   'A',
#   'R',
#   'A',
#   'P',
#   'A',
#   'C',
#   'A',
#   'O',
#   'V',
#   'R',
#   'A',
#   'C',
#   'W'],
#  ['N', 'C', 'A', 'V', 'R', 'A', 'R', 'D', 'A', 'V', 'N', 'O'],
#  ['C', 'A', 'N', 'V', 'R', 'A', 'A', 'C', 'A', 'C', 'D', 'A', 'O'],
#  ['A', 'O', 'N', 'V', 'R', 'V', 'N', 'N', 'R', 'N', 'A', 'V', 'O'],
#  ['P',
#   'A',
#   'A',
#   'V',
#   'C',
#   'A',
#   'A',
#   'C',
#   'A',
#   'W',
#   'N',
#   'A',
#   'C',
#   'D',
#   'A',
#   'A',
#   'A',
#   'C',
#   'D',
#   'N',
#   'R',
#   'V',
#   'D',
#   'N',
#   'R',
#   'N',
#   'A',
#   'P',
#   'A',
#   'N',
#   'O'],
#  ['C',
#   'D',
#   'N',
#   'O',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'C',
#   'O',
#   'R',
#   'A',
#   'O',
#   'O',
#   'V',
#   'R',
#   'V',
#   'O'],
#  ['N',
#   'A',
#   'V',
#   'C',
#   'N',
#   'W',
#   'D',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'M',
#   'V',
#   'A',
#   'O'],
#  ['V', 'P', 'N', 'R', 'D', 'A', 'V', 'C', 'A', 'O'],
#  ['D',
#   'A',
#   'A',
#   'O',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'V',
#   'D',
#   'A',
#   'N',
#   'R',
#   'V',
#   'A',
#   'N',
#   'C',
#   'A',
#   'V',
#   'V',
#   'A',
#   'N',
#   'C',
#   'A',
#   'O'],
#  ['A',
#   'N',
#   'V',
#   'R',
#   'A',
#   'A',
#   'C',
#   'N',
#   'C',
#   'A',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'W',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'P',
#   'N',
#   'C',
#   'A',
#   'O'],
#  ['N',
#   'R',
#   'C',
#   'N',
#   'V',
#   'A',
#   'O',
#   'N',
#   'R',
#   'V',
#   'R',
#   'R',
#   'N',
#   'A',
#   'O',
#   'V',
#   'C',
#   'D',
#   'N',
#   'A',
#   'P',
#   'N',
#   'N',
#   'A',
#   'N',
#   'C',
#   'A',
#   'O'],
#  ['A',
#   'V',
#   'R',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'C',
#   'D',
#   'N',
#   'R',
#   'A',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['C',
#   'N',
#   'C',
#   'A',
#   'N',
#   'V',
#   'V',
#   'R',
#   'A',
#   'C',
#   'D',
#   'N',
#   'V',
#   'N',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'C',
#   'O',
#   'W',
#   'A',
#   'O'],
#  ['D',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O',
#   'A',
#   'A',
#   'A',
#   'P',
#   'N',
#   'V',
#   'R',
#   'A',
#   'A',
#   'O',
#   'V',
#   'O',
#   'N',
#   'C',
#   'P',
#   'N',
#   'V',
#   'V',
#   'C',
#   'N',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'P',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'N',
#   'N',
#   'V',
#   'P',
#   'V',
#   'D',
#   'O',
#   'O',
#   'O',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'V',
#   'A',
#   'O',
#   'O'],
#  ['V', 'N', 'V', 'V', 'V', 'D', 'A', 'N', 'C', 'D', 'N', 'O'],
#  ['V',
#   'V',
#   'R',
#   'V',
#   'O',
#   'R',
#   'R',
#   'O',
#   'C',
#   'D',
#   'O',
#   'A',
#   'O',
#   'V',
#   'D',
#   'N',
#   'R',
#   'O'],
#  ['A', 'V', 'A', 'N', 'C', 'O', 'O', 'O', 'O', 'C', 'O', 'N'],
#  ['N', 'O', 'C', 'D', 'A', 'N', 'O'],
#  ['A',
#   'P',
#   'A',
#   'N',
#   'V',
#   'A',
#   'N',
#   'O',
#   'P',
#   'A',
#   'N',
#   'V',
#   'R',
#   'C',
#   'N',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'N',
#   'C',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['N',
#   'V',
#   'D',
#   'N',
#   'P',
#   'A',
#   'N',
#   'V',
#   'R',
#   'A',
#   'O',
#   'C',
#   'N',
#   'N',
#   'C',
#   'A',
#   'V',
#   'V',
#   'A',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'P',
#   'V',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O',
#   'N',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O',
#   'C',
#   'W',
#   'P',
#   'N',
#   'N',
#   'V',
#   'V',
#   'A',
#   'O'],
#  ['N', 'V', 'A', 'A', 'P', 'N', 'V', 'R', 'V', 'R', 'D', 'N', 'A', 'O'],
#  ['A', 'V', 'A', 'C', 'A', 'O', 'C', 'O', 'O'],
#  ['N', 'O'],
#  ['V', 'O', 'W'],
#  ['N', 'A', 'O', 'R', 'O', 'O', 'O', 'D', 'A', 'A', 'O', 'C', 'A', 'N', 'O'],
#  ['A', 'C', 'D', 'A', 'N', 'V', 'O', 'A'],
#  ['N', 'O'],
#  ['D', 'A', 'N', 'O', 'D', 'N', 'V', 'O', 'O', 'O', 'O', 'C', 'O', 'N'],
#  ['N', 'O', 'C', 'N', 'C', 'O', 'A', 'O', 'O'],
#  ['A',
#   'V',
#   'V',
#   'O',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O',
#   'R',
#   'R',
#   'O',
#   'N',
#   'C',
#   'P',
#   'A',
#   'O',
#   'N',
#   'O'],
#  ['V', 'D', 'V', 'V', 'R'],
#  ['N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'W',
#   'V',
#   'D',
#   'N',
#   'P',
#   'A',
#   'N',
#   'C',
#   'D',
#   'A',
#   'V',
#   'V',
#   'A',
#   'C',
#   'O',
#   'O'],
#  ['A',
#   'V',
#   'D',
#   'N',
#   'C',
#   'V',
#   'D',
#   'D',
#   'A',
#   'A',
#   'V',
#   'C',
#   'V',
#   'P',
#   'V',
#   'O',
#   'N',
#   'V',
#   'D',
#   'A',
#   'N',
#   'R',
#   'P',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'W',
#   'V',
#   'V',
#   'N',
#   'N',
#   'C',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'O'],
#  ['N', 'M', 'V', 'D', 'N', 'N', 'C', 'D', 'V', 'O'],
#  ['O'],
#  ['M', 'V', 'R', 'N', 'A', 'V', 'R', 'V', 'D', 'A', 'N', 'O'],
#  ['A',
#   'N',
#   'M',
#   'V',
#   'P',
#   'A',
#   'O',
#   'A',
#   'O',
#   'C',
#   'O',
#   'N',
#   'C',
#   'V',
#   'C',
#   'A',
#   'R',
#   'O'],
#  ['V',
#   'O',
#   'C',
#   'D',
#   'A',
#   'V',
#   'O',
#   'V',
#   'V',
#   'R',
#   'C',
#   'D',
#   'A',
#   'N',
#   'C',
#   'V',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O',
#   'V',
#   'R',
#   'C',
#   'O',
#   'A',
#   'O',
#   'C',
#   'A',
#   'O',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O',
#   'C',
#   'O',
#   'A',
#   'O',
#   'C',
#   'A',
#   'O',
#   'D',
#   'N',
#   'C',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'D',
#   'A',
#   'N',
#   'V',
#   'D',
#   'N',
#   'C',
#   'D',
#   'O',
#   'A',
#   'A',
#   'A',
#   'O',
#   'O',
#   'A',
#   'C',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['N',
#   'O',
#   'N',
#   'C',
#   'A',
#   'A',
#   'C',
#   'D',
#   'V',
#   'N',
#   'V',
#   'P',
#   'V',
#   'A',
#   'R',
#   'N',
#   'C',
#   'A',
#   'P',
#   'N',
#   'A',
#   'O'],
#  ['P', 'N', 'R', 'V', 'A', 'N', 'O'],
#  ['C',
#   'A',
#   'O',
#   'A',
#   'A',
#   'A',
#   'N',
#   'V',
#   'R',
#   'V',
#   'V',
#   'D',
#   'A',
#   'N',
#   'C',
#   'V',
#   'D',
#   'N'],
#  ['V', 'C', 'D', 'A', 'O', 'N', 'O', 'A', 'C', 'D', 'A', 'V', 'R', 'O'],
#  ['V',
#   'A',
#   'O',
#   'A',
#   'N',
#   'M',
#   'V',
#   'R',
#   'P',
#   'A',
#   'C',
#   'D',
#   'M',
#   'C',
#   'N',
#   'A',
#   'R',
#   'A',
#   'N',
#   'O'],
#  ['M', 'R', 'N', 'C', 'W', 'R', 'C', 'D', 'N', 'O'],
#  ['P',
#   'O',
#   'N',
#   'V',
#   'W',
#   'P',
#   'M',
#   'R',
#   'V',
#   'N',
#   'C',
#   'N',
#   'V',
#   'R',
#   'A',
#   'O'],
#  ['A',
#   'N',
#   'O',
#   'P',
#   'V',
#   'A',
#   'C',
#   'V',
#   'R',
#   'C',
#   'V',
#   'N',
#   'W',
#   'D',
#   'N',
#   'V',
#   'D',
#   'A',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'A',
#   'O',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O',
#   'W',
#   'V',
#   'O',
#   'O',
#   'O',
#   'C',
#   'N',
#   'O'],
#  ['A', 'V', 'D', 'P', 'N', 'C', 'N', 'A', 'C', 'O', 'P', 'A', 'N'],
#  ['V', 'V', 'R', 'O'],
#  ['A', 'V', 'R', 'V', 'D', 'N', 'C', 'D', 'N', 'A', 'R', 'O'],
#  ['N',
#   'N',
#   'A',
#   'A',
#   'V',
#   'R',
#   'A',
#   'W',
#   'A',
#   'P',
#   'A',
#   'A',
#   'O',
#   'O',
#   'O',
#   'C',
#   'D',
#   'N',
#   'C',
#   'D',
#   'O',
#   'A',
#   'O',
#   'A',
#   'A'],
#  ['V', 'O'],
#  ['A',
#   'V',
#   'R',
#   'V',
#   'A',
#   'D',
#   'D',
#   'N',
#   'N',
#   'V',
#   'V',
#   'C',
#   'O',
#   'O',
#   'P',
#   'V',
#   'O'],
#  ['P',
#   'V',
#   'C',
#   'D',
#   'N',
#   'O',
#   'O',
#   'A',
#   'V',
#   'O',
#   'O',
#   'O',
#   'C',
#   'D',
#   'A',
#   'A',
#   'O'],
#  ['O'],
#  ['N', 'N', 'R', 'V', 'P', 'A', 'O'],
#  ['A',
#   'V',
#   'V',
#   'C',
#   'D',
#   'R',
#   'O',
#   'A',
#   'O',
#   'C',
#   'N',
#   'M',
#   'V',
#   'V',
#   'R',
#   'C',
#   'A',
#   'V',
#   'P',
#   'V',
#   'V',
#   'A',
#   'N',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'A',
#   'O',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O',
#   'A',
#   'O',
#   'A',
#   'O'],
#  ['A', 'V', 'D', 'A', 'C', 'D', 'A', 'N', 'C', 'D', 'N', 'O'],
#  ['O'],
#  ['A',
#   'N',
#   'O',
#   'W',
#   'M',
#   'V',
#   'V',
#   'R',
#   'V',
#   'A',
#   'W',
#   'N',
#   'W',
#   'R',
#   'V',
#   'N',
#   'O',
#   'A',
#   'N',
#   'A',
#   'C',
#   'N',
#   'N',
#   'C',
#   'N',
#   'N',
#   'M',
#   'V',
#   'R',
#   'V',
#   'R',
#   'N',
#   'A',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['R',
#   'O',
#   'P',
#   'V',
#   'R',
#   'W',
#   'O',
#   'C',
#   'N',
#   'V',
#   'V',
#   'R',
#   'V',
#   'D',
#   'A',
#   'A',
#   'N',
#   'O',
#   'V',
#   'C',
#   'O',
#   'O',
#   'O',
#   'C',
#   'N',
#   'N',
#   'R',
#   'O'],
#  ['A',
#   'P',
#   'V',
#   'C',
#   'D',
#   'N',
#   'O',
#   'P',
#   'V',
#   'R',
#   'R',
#   'R',
#   'R',
#   'D',
#   'A',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'A',
#   'O',
#   'A',
#   'N',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'A',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O',
#   'C',
#   'O',
#   'O',
#   'V',
#   'O',
#   'O',
#   'O',
#   'R',
#   'P',
#   'N',
#   'N',
#   'O',
#   'N',
#   'R',
#   'O'],
#  ['A',
#   'A',
#   'N',
#   'V',
#   'A',
#   'N',
#   'W',
#   'P',
#   'V',
#   'R',
#   'V',
#   'A',
#   'N',
#   'O',
#   'C',
#   'W',
#   'P',
#   'M',
#   'R',
#   'V',
#   'R',
#   'A',
#   'N',
#   'O',
#   'A',
#   'C',
#   'A',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'A',
#   'O',
#   'A',
#   'N',
#   'N',
#   'C',
#   'D',
#   'N',
#   'N',
#   'A',
#   'A',
#   'C',
#   'A',
#   'A',
#   'O',
#   'A',
#   'O'],
#  ['A'],
#  ['V',
#   'R',
#   'O',
#   'C',
#   'N',
#   'O',
#   'A',
#   'P',
#   'O',
#   'O',
#   'P',
#   'V',
#   'O',
#   'O',
#   'R',
#   'A',
#   'N',
#   'P',
#   'M',
#   'V',
#   'D',
#   'A',
#   'N',
#   'O',
#   'C',
#   'A',
#   'N',
#   'C',
#   'D',
#   'N',
#   'C',
#   'A',
#   'P',
#   'N',
#   'O'],
#  ['O',
#   'C',
#   'V',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'P',
#   'A',
#   'N',
#   'O',
#   'V',
#   'V',
#   'A',
#   'W'],
#  ['N', 'O', 'V', 'A', 'N', 'C', 'A', 'P', 'N', 'O', 'V', 'N', 'O'],
#  ['A',
#   'P',
#   'N',
#   'V',
#   'N',
#   'R',
#   'A',
#   'C',
#   'O',
#   'N',
#   'O',
#   'R',
#   'C',
#   'D',
#   'A',
#   'A',
#   'C',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O'],
#  ['N',
#   'M',
#   'V',
#   'R',
#   'O',
#   'N',
#   'C',
#   'R',
#   'V',
#   'D',
#   'A',
#   'N',
#   'C',
#   'D',
#   'N',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'A',
#   'O',
#   'N',
#   'C',
#   'A',
#   'A',
#   'A',
#   'A',
#   'A',
#   'O'],
#  ['A',
#   'O',
#   'R',
#   'O',
#   'N',
#   'W',
#   'D',
#   'N',
#   'O',
#   'M',
#   'V',
#   'R',
#   'O',
#   'C',
#   'O',
#   'N',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['M', 'V', 'C', 'P', 'M', 'V', 'C', 'O'],
#  ['A',
#   'V',
#   'P',
#   'A',
#   'A',
#   'A',
#   'C',
#   'O',
#   'O',
#   'V',
#   'D',
#   'N',
#   'C',
#   'N',
#   'N',
#   'C',
#   'D',
#   'A',
#   'C',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['A', 'R', 'N'],
#  ['V',
#   'R',
#   'V',
#   'O',
#   'O',
#   'P',
#   'V',
#   'O',
#   'O',
#   'V',
#   'D',
#   'O',
#   'N',
#   'N',
#   'P',
#   'N',
#   'A',
#   'C',
#   'D',
#   'N',
#   'O'],
#  ['O'],
#  ['A',
#   'N',
#   'V',
#   'V',
#   'D',
#   'N',
#   'N',
#   'V',
#   'N',
#   'O',
#   'W',
#   'V',
#   'R',
#   'V',
#   'R',
#   'V',
#   'A',
#   'D',
#   'O',
#   'N',
#   'O'],
#  ['R',
#   'N',
#   'O',
#   'D',
#   'A',
#   'V',
#   'V',
#   'R',
#   'V',
#   'D',
#   'N',
#   'C',
#   'V',
#   'N',
#   'N',
#   'C',
#   'V',
#   'D',
#   'V',
#   'N',
#   'C',
#   'V',
#   'N',
#   'C',
#   'A',
#   'N',
#   'N',
#   'O'],
#  ['P',
#   'A',
#   'N',
#   'O',
#   'D',
#   'O',
#   'O',
#   'O',
#   'C',
#   'N',
#   'N',
#   'C',
#   'N',
#   'C',
#   'D',
#   'O',
#   'N',
#   'V',
#   'R',
#   'V',
#   'O',
#   'C',
#   'N',
#   'N',
#   'V',
#   'C',
#   'N',
#   'C',
#   'N',
#   'N',
#   'V',
#   'A',
#   'O'],
#  ['C', 'N', 'N', 'O', 'N', 'N', 'V', 'A', 'A', 'O', 'N', 'N', 'V', 'O'],
#  ['A', 'O', 'W'],
#  ['A',
#   'A',
#   'A',
#   'A',
#   'V',
#   'V',
#   'O',
#   'N',
#   'C',
#   'P',
#   'O',
#   'W',
#   'O',
#   'N',
#   'N',
#   'R',
#   'N',
#   'C',
#   'A',
#   'N',
#   'O',
#   'V',
#   'P',
#   'V',
#   'A',
#   'C',
#   'A',
#   'A',
#   'N',
#   'A',
#   'V',
#   'P',
#   'R',
#   'V',
#   'N',
#   'R',
#   'P',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'V',
#   'C',
#   'A',
#   'V',
#   'N',
#   'V',
#   'P',
#   'C',
#   'P',
#   'V',
#   'R',
#   'V',
#   'N',
#   'C',
#   'N',
#   'O',
#   'O',
#   'V',
#   'A',
#   'A',
#   'O',
#   'W',
#   'O',
#   'A',
#   'C',
#   'P',
#   'N',
#   'C',
#   'N',
#   'A',
#   'R',
#   'R',
#   'O',
#   'V',
#   'D',
#   'V',
#   'O'],
#  ['A',
#   'V',
#   'N',
#   'M',
#   'V',
#   'R',
#   'V',
#   'C',
#   'D',
#   'A',
#   'A',
#   'N',
#   'C',
#   'V',
#   'R',
#   'O',
#   'A',
#   'A',
#   'N',
#   'O'],
#  ['A', 'V', 'P', 'M', 'V', 'D', 'A', 'A', 'N', 'O', 'O', 'P', 'V', 'O'],
#  ['O',
#   'A',
#   'V',
#   'D',
#   'A',
#   'C',
#   'N',
#   'N',
#   'W',
#   'N',
#   'W',
#   'V',
#   'V',
#   'P',
#   'C',
#   'N',
#   'C',
#   'D',
#   'N',
#   'N',
#   'O'],
#  ['A',
#   'V',
#   'D',
#   'A',
#   'N',
#   'O',
#   'W',
#   'V',
#   'V',
#   'A',
#   'C',
#   'D',
#   'N',
#   'P',
#   'N',
#   'V',
#   'O'],
#  ['A',
#   'V',
#   'V',
#   'N',
#   'O',
#   'V',
#   'R',
#   'N',
#   'C',
#   'V',
#   'P',
#   'R',
#   'C',
#   'D',
#   'A',
#   'N',
#   'O'],
#  ['N',
#   'P',
#   'A',
#   'A',
#   'N',
#   'V',
#   'A',
#   'A',
#   'O',
#   'A',
#   'A',
#   'O',
#   'A',
#   'O',
#   'W',
#   'V',
#   'A',
#   'A',
#   'W',
#   'P',
#   'A',
#   'N',
#   'V',
#   'V',
#   'N',
#   'C',
#   'O',
#   'N',
#   'C',
#   'D',
#   'N',
#   'R',
#   'R',
#   'W',
#   'N',
#   'O'],
#  ['A'],
#  ['R', 'V', 'V', 'O'],
#  ['A',
#   'V',
#   'R',
#   'C',
#   'D',
#   'N',
#   'C',
#   'C',
#   'A',
#   'O',
#   'O',
#   'V',
#   'D',
#   'N',
#   'P',
#   'A',
#   'A',
#   'O'],
#  ['A', 'V', 'R', 'V', 'D', 'V', 'O', 'C', 'P', 'V', 'D', 'A', 'N', 'O'],
#  ['O'],
#  ['V', 'A', 'A', 'O', 'A', 'C', 'A', 'N', 'V', 'R', 'V', 'C', 'N'],
#  ['N', 'O', 'V', 'R', 'A', 'A', 'A', 'A', 'A', 'O'],
#  ...]

# %%
tst_data=[]
tst_final=[]
for i,row in enumerate(tst):
    row_split = row.split()
    print(row)
    tst_data=[]
    for j,word in enumerate(row_split):
        if(word=='.' or word=='``' or word=='\''):
            token=word + "/O"
            tst_data.append(token)
            continue
        token= word + "/"+ df_tag_pred[i][j]
        tst_data.append(token)
    tst_sent=""
    for j,combo in enumerate(tst_data):
        if j==0:
            tst_sent=combo
        else:
            tst_sent=tst_sent+" "+combo
    tst_final.append(tst_sent)
# Out:
# Newspaper publishers are reporting mixed third-quarter results , aided by favorable newsprint prices and hampered by flat or declining advertising linage , especially in the Northeast .
# Adding to unsteadiness in the industry , seasonal retail ad spending patterns in newspapers have been upset by shifts in ownership and general hardships within the retail industry .
# In New York , the Bonwit Teller and B. Altman & Co. department stores have filed for protection from creditors under Chapter 11 of the federal Bankruptcy Code , while the R.H. Macy & Co. , Bloomingdale 's and Saks Fifth Avenue department-store chains are for sale .
# Many papers throughout the country are also faced with a slowdown in classified-ad spending , a booming category for newspapers in recent years .
# Until recently , industry analysts believed decreases in retail ad spending had bottomed out and would in fact increase in this year 's third and fourth quarters .
# All bets are off , analysts say , because of the shifting ownership of the retail chains .
# `` Improved paper prices will help offset weakness in linage , but the retailers ' problems have affected the amount of ad linage
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-5f478cc0c42d> in <module>()
#      10             tst_data.append(token)
#      11             continue
# ---> 12         token= word + "/"+ df_tag_pred[i][j]
#      13         tst_data.append(token)
#      14     tst_sent=""
#
# IndexError: list index out of range

# %%
df_tag_pred[7]
# Out:
# ['R',
#  'V',
#  'O',
#  'O',
#  'V',
#  'A',
#  'A',
#  'A',
#  'O',
#  'N',
#  'N',
#  'C',
#  'A',
#  'A',
#  'A',
#  'O']

# %%
txt_file = "og7ut-viterbi.txt"
with open(txt_file,"w") as output_file:
    for row in tst_final:
            output_file.write("\n".join(row))
